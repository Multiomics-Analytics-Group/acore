# %% [markdown]
# # Metabolomics drift correction

# %% [markdown]
# Within-batch correction of metabolomics data. This notebook shows how to correct for
# instrumental drift based on pooled QC data samples.

# %% [markdown]
# ## 1. LOESS smoothing-based drift correction

# %% [markdown]
# First, let's load our packages, including acore.

# %%
# %pip install acore
# Out:
# Requirement already satisfied: acore in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (0.2.1.dev9+ge03aa2e77.d20251006)
# Requirement already satisfied: numpy<2.1.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from acore) (2.0.2)
# Requirement already satisfied: pandas in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from acore) (2.3.3)
# Requirement already satisfied: dsp-pandas in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from acore) (0.0.5)
# Requirement already satisfied: vuecore in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from acore) (0.1.1)
# Requirement already satisfied: scipy in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from acore) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.5 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from acore) (1.7.2)
# Requirement already satisfied: networkx in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from acore) (3.5)
# Requirement already satisfied: biopython in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from acore) (1.85)
# Requirement already satisfied: combat in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from acore) (0.3.3)
# Requirement already satisfied: gseapy!=1.1.5 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from acore) (1.1.10)
# Requirement already satisfied: kmapper in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from acore) (2.1.0)
# Requirement already satisfied: lifelines in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from acore) (0.30.0)
# Requirement already satisfied: pingouin in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from acore) (0.5.5)
# Requirement already satisfied: python-louvain in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from acore) (0.16)
# Requirement already satisfied: PyWGCNA!=2.2.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from acore) (2.1.3)
# Requirement already satisfied: snfpy in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from acore) (0.2.2)
# Requirement already satisfied: umap-learn in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from acore) (0.5.9.post2)
# Requirement already satisfied: statsmodels in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from acore) (0.14.5)
# Requirement already satisfied: inmoose in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from acore) (0.8.1)
# Requirement already satisfied: requests in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from acore) (2.32.5)
# Requirement already satisfied: rarfile in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from acore) (4.2)
# Requirement already satisfied: matplotlib>=2.2 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from gseapy!=1.1.5->acore) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy!=1.1.5->acore) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy!=1.1.5->acore) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy!=1.1.5->acore) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy!=1.1.5->acore) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy!=1.1.5->acore) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy!=1.1.5->acore) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy!=1.1.5->acore) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy!=1.1.5->acore) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->gseapy!=1.1.5->acore) (1.17.0)
# Requirement already satisfied: seaborn>=0.11.2 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from PyWGCNA!=2.2.0->acore) (0.13.2)
# Requirement already satisfied: biomart>=0.9.2 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from PyWGCNA!=2.2.0->acore) (0.9.2)
# Requirement already satisfied: pyvis==0.3.1 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from PyWGCNA!=2.2.0->acore) (0.3.1)
# Requirement already satisfied: setuptools>=67.4.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from PyWGCNA!=2.2.0->acore) (80.9.0)
# Requirement already satisfied: reactome2py>=3.0.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from PyWGCNA!=2.2.0->acore) (3.0.0)
# Requirement already satisfied: anndata>=0.10.8 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from PyWGCNA!=2.2.0->acore) (0.12.2)
# Requirement already satisfied: rsrc>=0.1.3 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from PyWGCNA!=2.2.0->acore) (0.1.3)
# Requirement already satisfied: psutil>=5.9.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from PyWGCNA!=2.2.0->acore) (7.1.0)
# Requirement already satisfied: jinja2>=2.9.6 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from pyvis==0.3.1->PyWGCNA!=2.2.0->acore) (3.1.6)
# Requirement already satisfied: ipython>=5.3.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from pyvis==0.3.1->PyWGCNA!=2.2.0->acore) (9.6.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from pyvis==0.3.1->PyWGCNA!=2.2.0->acore) (4.1.1)
# Requirement already satisfied: array-api-compat>=1.7.1 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from anndata>=0.10.8->PyWGCNA!=2.2.0->acore) (1.12.0)
# Requirement already satisfied: h5py>=3.8 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from anndata>=0.10.8->PyWGCNA!=2.2.0->acore) (3.14.0)
# Requirement already satisfied: legacy-api-wrap in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from anndata>=0.10.8->PyWGCNA!=2.2.0->acore) (1.4.1)
# Requirement already satisfied: natsort in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from anndata>=0.10.8->PyWGCNA!=2.2.0->acore) (8.4.0)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from anndata>=0.10.8->PyWGCNA!=2.2.0->acore) (3.1.3)
# Requirement already satisfied: decorator in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.3.1->PyWGCNA!=2.2.0->acore) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.3.1->PyWGCNA!=2.2.0->acore) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.3.1->PyWGCNA!=2.2.0->acore) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.3.1->PyWGCNA!=2.2.0->acore) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.3.1->PyWGCNA!=2.2.0->acore) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.3.1->PyWGCNA!=2.2.0->acore) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.3.1->PyWGCNA!=2.2.0->acore) (2.19.2)
# Requirement already satisfied: stack_data in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.3.1->PyWGCNA!=2.2.0->acore) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.3.1->PyWGCNA!=2.2.0->acore) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.3.1->PyWGCNA!=2.2.0->acore) (4.15.0)
# Requirement already satisfied: wcwidth in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis==0.3.1->PyWGCNA!=2.2.0->acore) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis==0.3.1->PyWGCNA!=2.2.0->acore) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from jinja2>=2.9.6->pyvis==0.3.1->PyWGCNA!=2.2.0->acore) (3.0.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from pandas->acore) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from pandas->acore) (2025.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis==0.3.1->PyWGCNA!=2.2.0->acore) (0.7.0)
# Requirement already satisfied: json5>=0.8.4 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from reactome2py>=3.0.0->PyWGCNA!=2.2.0->acore) (0.12.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from requests->acore) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from requests->acore) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from requests->acore) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from requests->acore) (2025.10.5)
# Requirement already satisfied: memoir>=0.0.3 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from rsrc>=0.1.3->PyWGCNA!=2.2.0->acore) (0.0.3)
# Requirement already satisfied: reprit>=0.3.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from rsrc>=0.1.3->PyWGCNA!=2.2.0->acore) (0.9.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from scikit-learn>=1.5->acore) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from scikit-learn>=1.5->acore) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from statsmodels->acore) (1.0.1)
# Requirement already satisfied: donfig>=0.8 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->PyWGCNA!=2.2.0->acore) (0.8.1.post1)
# Requirement already satisfied: numcodecs>=0.14 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->PyWGCNA!=2.2.0->acore) (0.16.3)
# Requirement already satisfied: pyyaml in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->PyWGCNA!=2.2.0->acore) (6.0.3)
# Requirement already satisfied: crc32c>=2.7 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->PyWGCNA!=2.2.0->acore) (2.7.1)
# Requirement already satisfied: mpmath>=1.1.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from combat->acore) (1.3.0)
# Requirement already satisfied: openpyxl in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from dsp-pandas->acore) (3.1.5)
# Requirement already satisfied: fastcluster in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from inmoose->acore) (1.3.0)
# Requirement already satisfied: autograd>=1.5 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from lifelines->acore) (1.8.0)
# Requirement already satisfied: autograd-gamma>=0.3 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from lifelines->acore) (0.5.0)
# Requirement already satisfied: formulaic>=0.2.2 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from lifelines->acore) (1.2.1)
# Requirement already satisfied: interface-meta>=1.2.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from formulaic>=0.2.2->lifelines->acore) (1.3.0)
# Requirement already satisfied: narwhals>=1.17 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from formulaic>=0.2.2->lifelines->acore) (2.7.0)
# Requirement already satisfied: wrapt>=1.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from formulaic>=0.2.2->lifelines->acore) (1.17.3)
# Requirement already satisfied: et-xmlfile in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from openpyxl->dsp-pandas->acore) (2.0.0)
# Requirement already satisfied: pandas-flavor in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from pingouin->acore) (0.7.0)
# Requirement already satisfied: tabulate in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from pingouin->acore) (0.9.0)
# Requirement already satisfied: xarray in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from pandas-flavor->pingouin->acore) (2025.9.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from stack_data->ipython>=5.3.0->pyvis==0.3.1->PyWGCNA!=2.2.0->acore) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from stack_data->ipython>=5.3.0->pyvis==0.3.1->PyWGCNA!=2.2.0->acore) (3.0.0)
# Requirement already satisfied: pure_eval in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from stack_data->ipython>=5.3.0->pyvis==0.3.1->PyWGCNA!=2.2.0->acore) (0.2.3)
# Requirement already satisfied: numba>=0.51.2 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from umap-learn->acore) (0.62.1)
# Requirement already satisfied: pynndescent>=0.5 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from umap-learn->acore) (0.5.13)
# Requirement already satisfied: tqdm in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from umap-learn->acore) (4.67.1)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from numba>=0.51.2->umap-learn->acore) (0.45.1)
# Requirement already satisfied: plotly in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from vuecore->acore) (6.3.1)
# Requirement already satisfied: beautifulsoup4 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from vuecore->acore) (4.14.2)
# Requirement already satisfied: dash in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from vuecore->acore) (3.2.0)
# Requirement already satisfied: kaleido in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from vuecore->acore) (1.1.0)
# Requirement already satisfied: wordcloud in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from vuecore->acore) (1.9.4)
# Requirement already satisfied: cyjupyter in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from vuecore->acore) (0.2.0)
# Requirement already satisfied: nltk in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from vuecore->acore) (3.9.2)
# Requirement already satisfied: webweb in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from vuecore->acore) (0.0.37)
# Requirement already satisfied: dash-cytoscape in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from vuecore->acore) (1.0.2)
# Requirement already satisfied: pydantic in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from vuecore->acore) (2.11.10)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from vuecore->acore) (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from nbformat>=4.2.0->vuecore->acore) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from nbformat>=4.2.0->vuecore->acore) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from nbformat>=4.2.0->vuecore->acore) (5.8.1)
# Requirement already satisfied: attrs>=22.2.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->vuecore->acore) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->vuecore->acore) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->vuecore->acore) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->vuecore->acore) (0.27.1)
# Requirement already satisfied: platformdirs>=2.5 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->vuecore->acore) (4.4.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from beautifulsoup4->vuecore->acore) (2.8)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from cyjupyter->vuecore->acore) (8.1.7)
# Requirement already satisfied: comm>=0.1.3 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from ipywidgets>=7.0.0->cyjupyter->vuecore->acore) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from ipywidgets>=7.0.0->cyjupyter->vuecore->acore) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from ipywidgets>=7.0.0->cyjupyter->vuecore->acore) (3.0.15)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from dash->vuecore->acore) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from dash->vuecore->acore) (3.1.3)
# Requirement already satisfied: importlib-metadata in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from dash->vuecore->acore) (8.7.0)
# Requirement already satisfied: retrying in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from dash->vuecore->acore) (1.4.2)
# Requirement already satisfied: nest-asyncio in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from dash->vuecore->acore) (1.6.0)
# Requirement already satisfied: blinker>=1.9.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from Flask<3.2,>=1.0.4->dash->vuecore->acore) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from Flask<3.2,>=1.0.4->dash->vuecore->acore) (8.3.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from Flask<3.2,>=1.0.4->dash->vuecore->acore) (2.2.0)
# Requirement already satisfied: zipp>=3.20 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from importlib-metadata->dash->vuecore->acore) (3.23.0)
# Requirement already satisfied: choreographer>=1.0.10 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from kaleido->vuecore->acore) (1.1.1)
# Requirement already satisfied: logistro>=1.0.8 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from kaleido->vuecore->acore) (1.1.0)
# Requirement already satisfied: orjson>=3.10.15 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from kaleido->vuecore->acore) (3.11.3)
# Requirement already satisfied: pytest-timeout>=2.4.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from kaleido->vuecore->acore) (2.4.0)
# Requirement already satisfied: simplejson>=3.19.3 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from choreographer>=1.0.10->kaleido->vuecore->acore) (3.20.2)
# Requirement already satisfied: pytest>=7.0.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from pytest-timeout>=2.4.0->kaleido->vuecore->acore) (8.4.2)
# Requirement already satisfied: iniconfig>=1 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido->vuecore->acore) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido->vuecore->acore) (1.6.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from nltk->vuecore->acore) (2025.9.18)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from pydantic->vuecore->acore) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from pydantic->vuecore->acore) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/fcasc/miniconda3/envs/acore-dev/lib/python3.11/site-packages (from pydantic->vuecore->acore) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

from acore import drift_correction as dc

# %%
def plot_loess_example_curve(
    df: pd.DataFrame,
    feature_idx: int,
    sample_cols: list,
    qc_cols: list,
    sample_order: pd.DataFrame,
    feature_name_col: str = None,
    show_corrected: bool = True,
    alpha: float = None,  # fixed smoothing span; if None, selected by LOOCV
):
    """
    Plot the raw intensities, LOESS drift curve, and optionally the corrected
    intensities for a single feature according to the loess drift correction function.
    Useful for inspecting drift behaviour before running full drift correction.

    The drift curve is estimated with the same method used by
    ldc.run_drift_correction: LOESS is fit to the QC points and then
    interpolated across all injection positions via a cubic spline
    (qc_rlsc_loess).

    Parameters
    ----------
    df : pd.DataFrame
        Feature matrix with features as rows and samples/QCs as columns.
    feature_idx : int
        Row index of the feature to plot.
    sample_cols : list of str
        Column names of the biological samples.
    qc_cols : list of str
        Column names of the pooled QC samples.
    sample_order : pd.DataFrame
        Injection-order table with columns "File Name" and "Sample ID"
        (integer run order).
    feature_name_col : str, optional
        Column in df containing feature identifiers used in the plot title.
        If None, the row index is used.
    show_corrected : bool, optional
        If True (default), overlays drift-corrected sample intensities as
        diamond markers.
    alpha : float, optional
        LOESS smoothing span (0 < α ≤ 1). If None (default), the optimal span
        is selected automatically by leave-one-out cross-validation over
        α ∈ [0.40, 1.00]. The selected value is shown in the legend.
    """

    feature_row = df.iloc[feature_idx]
    all_cols = sample_cols + qc_cols

    order_dict = sample_order.set_index("File Name")["Sample ID"].to_dict()
    x_all = np.array([order_dict.get(c, np.nan) for c in all_cols])
    y_all = feature_row[all_cols].astype(float).values

    n_s = len(sample_cols)
    x_sample, y_sample = x_all[:n_s], y_all[:n_s]
    x_qc_arr, y_qc_arr = x_all[n_s:], y_all[n_s:]

    valid_sample = ~np.isnan(x_sample) & ~np.isnan(y_sample)
    valid_qc = ~np.isnan(x_qc_arr) & ~np.isnan(y_qc_arr)
    x_s_v, y_s_v = x_sample[valid_sample], y_sample[valid_sample]
    x_qc_v, y_qc_v = x_qc_arr[valid_qc], y_qc_arr[valid_qc]

    if feature_name_col and feature_name_col in df.columns:
        feature_name = feature_row[feature_name_col]
    else:
        feature_name = f"index {feature_idx}"

    fig, ax = plt.subplots(figsize=(11, 5))
    ax.scatter(x_s_v, y_s_v, label="Samples", color="steelblue", alpha=0.7, zorder=3)
    ax.scatter(
        x_qc_v, y_qc_v, label="QC", color="firebrick", edgecolor="k", s=60, zorder=4
    )

    if len(x_qc_v) >= 4:
        if alpha is not None:
            # Pass a single-element candidate list to skip LOOCV and use the given alpha
            # directly
            drift_curve, best_alpha = dc.qc_rlsc_loess(
                x_qc_v, y_qc_v, x_all, use_default=True, default=alpha
            )
        else:
            drift_curve, best_alpha = dc.qc_rlsc_loess(x_qc_v, y_qc_v, x_all)

        valid_curve = ~np.isnan(x_all) & ~np.isnan(drift_curve)
        sort_idx = np.argsort(x_all[valid_curve])
        ax.plot(
            x_all[valid_curve][sort_idx],
            drift_curve[valid_curve][sort_idx],
            label=f"LOESS drift curve (α={best_alpha:.2f})",
            color="black",
            lw=2,
            zorder=5,
        )

        if show_corrected:
            median_qc = np.median(y_qc_v)
            drift_at_samples = drift_curve[:n_s][valid_sample]
            corrected = (y_s_v / drift_at_samples) * median_qc
            ax.scatter(
                x_s_v,
                corrected,
                label="Corrected samples",
                color="lightsteelblue",
                marker="D",
                s=40,
                alpha=0.9,
                zorder=3,
            )
    else:
        print(f"Not enough valid QC points for LOESS ({len(x_qc_v)} found, need ≥4).")

    ax.set_xlabel("Injection Order")
    ax.set_ylabel("Intensity")
    ax.set_title(f"Drift correction example ({feature_name})")
    ax.legend()
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()


def pca_for_cpca_drift(
    df: pd.DataFrame,
    sample_cols,  # list of col names, OR dict {group_name: [col names]}
    qc_cols: list,
    log_transform: bool = True,
    title: str = "PCA",
):
    """
    PCA of samples and QC samples.

    Parameters
    ----------
    df          : feature matrix with features as rows, samples as columns
    sample_cols : list of sample column names (all one group),
                  or dict {group_name: [col names]} for multiple groups
    qc_cols     : list of QC column names
    log_transform : apply log1p before scaling
    title       : plot title
    """
    # Normalise sample_cols to a dict
    if isinstance(sample_cols, list):
        sample_groups = {"Samples": sample_cols}
    else:
        sample_groups = sample_cols

    # Build ordered column + label arrays
    all_cols, labels = [], []
    for group, cols in sample_groups.items():
        for c in cols:
            if c in df.columns:
                all_cols.append(c)
                labels.append(group)
    for c in qc_cols:
        if c in df.columns:
            all_cols.append(c)
            labels.append("QC")

    # Coerce to numeric, drop features with any NaN
    X = df[all_cols].apply(pd.to_numeric, errors="coerce").dropna(axis=0)

    if log_transform:
        X = np.log1p(X.clip(lower=0))

    X_scaled = StandardScaler().fit_transform(X.T.values.astype(float))

    pca = PCA(n_components=2)
    coords = pca.fit_transform(X_scaled)
    pc1_var = pca.explained_variance_ratio_[0] * 100
    pc2_var = pca.explained_variance_ratio_[1] * 100

    palette = plt.cm.tab10.colors
    color_map = {g: palette[i % len(palette)] for i, g in enumerate(sample_groups)}
    color_map["QC"] = "black"

    fig, ax = plt.subplots(figsize=(8, 6))
    for group in list(sample_groups) + ["QC"]:
        mask = [_label == group for _label in labels]
        pts = coords[mask]
        is_qc = group == "QC"
        ax.scatter(
            pts[:, 0],
            pts[:, 1],
            label=group,
            color=color_map[group],
            marker="D" if is_qc else "o",
            s=70 if is_qc else 50,
            edgecolors="k" if is_qc else "none",
            alpha=0.9 if is_qc else 0.75,
            zorder=5 if is_qc else 3,
        )

    ax.set_xlabel(f"PC1 ({pc1_var:.1f}%)")
    ax.set_ylabel(f"PC2 ({pc2_var:.1f}%)")
    ax.set_title(title)
    ax.axhline(0, color="grey", lw=0.5, ls="--")
    ax.axvline(0, color="grey", lw=0.5, ls="--")
    ax.legend(framealpha=0.8)
    ax.grid(True, alpha=0.2)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Load in data

# %% [markdown]
# We will use some example data that can be found in this repo.

# %%
data_path = (
    "https://raw.githubusercontent.com/Multiomics-Analytics-Group/acore/"
    "refs/heads/main/"
)

df = pd.read_csv(
    "../../example_data/DidacMauricio_hilic/DM_FIS2018_Hilic_pos_results2023_filled_imputed.csv",
    index_col=0,
)

# %% [markdown]
# This is what the data frame, an intensity table, looks like.

# %%
df
# Out:
#        Qidx  SOIidx   rtmed   start     end    mass        MaxInt  \
# 0         1       1  60.544  45.000  72.500  81.070   160,840.953
# 1         2       4 172.568 161.439 191.635  82.053    98,153.547
# 2         3       6 143.225 116.953 165.260  82.053   134,492.109
# 3         4       7 330.747 313.125 373.976  82.065    67,051.617
# 4         5       7 343.980 313.125 373.976  82.065    67,051.617
# ...     ...     ...     ...     ...     ...     ...           ...
# 2,539 2,540   2,363 290.896 290.000 312.500 892.654 3,486,662.000
# 2,540 2,541   2,363 299.617 290.000 312.500 892.654 3,486,662.000
# 2,541 2,542   2,364  54.789  50.000  67.500 892.739   179,925.600
# 2,542 2,543   2,365  54.782  50.000  67.500 894.755   488,985.200
# 2,544 2,545   2,367  54.821  50.000  67.500 896.770   843,227.000
#
#               formula             anot    AAA9485207  ...         QC_35  \
# 0             [C6H9]+         C6H8_M+H   279,488.531  ...   142,100.734
# 1           [C4H6N2]+       C4H5N2_M+H    73,170.344  ...    72,917.398
# 2           [C4H6N2]+       C4H5N2_M+H   106,222.969  ...   117,823.602
# 3            [C5H8N]+        C5H7N_M+H    40,187.371  ...    58,493.379
# 4            [C5H8N]+        C5H7N_M+H    16,231.437  ...    25,015.951
# ...               ...              ...           ...  ...           ...
# 2,539  [C48H94NO11S]+  C48H93NO11S_M+H 6,403,619.000  ... 4,217,977.000
# 2,540  [C48H94NO11S]+  C48H93NO11S_M+H   137,733.500  ...    66,690.800
# 2,541    [C57H98NO6]+   C57H94O6_M+NH4   130,200.000  ...   190,497.800
# 2,542   [C57H100NO6]+   C57H96O6_M+NH4   468,793.800  ...   523,346.000
# 2,544   [C57H102NO6]+   C57H98O6_M+NH4   821,122.200  ...   998,584.700
#
#               QC_36         QC_37         QC_38         QC_39         QC_40  \
# 0       129,631.148   110,443.422   157,871.062   535,311.375   334,133.656
# 1        73,738.812    65,597.875    78,216.859    70,257.375    73,489.242
# 2       122,279.500   120,513.508   119,803.422   114,791.906   124,753.789
# 3        55,851.680    58,560.121    57,886.605    58,293.699    46,211.445
# 4        21,309.277    20,180.580    19,609.604    25,462.301    24,354.287
# ...             ...           ...           ...           ...           ...
# 2,539 3,872,732.000 3,356,819.000 3,444,360.000 3,641,683.000 4,531,348.000
# 2,540    53,758.060   100,864.900    88,069.460    94,612.190    87,438.410
# 2,541   173,043.300    57,476.910   174,392.000    47,625.360   135,338.900
# 2,542   453,992.800   133,935.100   509,662.500   114,995.100   381,900.100
# 2,544   897,026.200   235,440.700   809,741.600   178,420.900   678,957.200
#
#               QC_41         QC_42         QC_43         QC_44
# 0       339,973.344   317,506.188   294,083.344   234,717.266
# 1        60,233.695    70,798.312    69,802.516    74,212.203
# 2       128,157.016   115,411.750   133,331.281   124,152.578
# 3        62,802.289    57,658.062    54,058.363    54,484.602
# 4        30,869.357    17,454.047    22,235.070    18,160.814
# ...             ...           ...           ...           ...
# 2,539 4,375,519.000 3,864,418.000 3,730,628.000 5,249,600.000
# 2,540    78,174.880    61,854.690    92,978.760    69,441.320
# 2,541   154,609.500   179,258.000   171,145.200   161,171.100
# 2,542   421,614.900   503,656.400   439,513.500   434,035.700
# 2,544   785,135.600   895,259.400   788,261.100   768,748.800
#
# [2287 rows x 486 columns]

# %% [markdown]
# We also have data that contains the order in which our samples were run. This
# information is crucial for the drift correction algorithm; it cannot be performed without it.
#
# The data needs to contain the columns "File Name" and "Sample ID", referring to the name of the sample and the index of the sample, meaning the order in which the samples were run.
#
# Note: If you do not have metadata that contains the order in which samples and QCs were run, you can use the second method explained in this notebook, CPCA (scroll down).

# %%
sample_order = pd.read_csv(
    "../../example_data/DidacMauricio_hilic/DidacMauricio_hilic_pos_injectionorder.csv"
)
sample_order["File Name"] = sample_order["SampleName"]
sample_order["Sample ID"] = sample_order["injectionOrder"]

sample_order
# Out:
#      SampleName          measureTime  injectionOrder   File Name  Sample ID
# 0          Bi_1  2021-07-19 13:51:34               1        Bi_1          1
# 1          Bi_2  2021-07-19 14:05:49               2        Bi_2          2
# 2         QC_00  2021-07-19 14:20:04               3       QC_00          3
# 3         QC_01  2021-07-19 14:34:20               4       QC_01          4
# 4         QC_02  2021-07-19 14:48:36               5       QC_02          5
# ..          ...                  ...             ...         ...        ...
# 472  AAA9516105  2021-07-24 06:04:54             473  AAA9516105        473
# 473       QC_43  2021-07-24 06:19:11             474       QC_43        474
# 474       QC_44  2021-07-24 06:33:27             475       QC_44        475
# 475        Bf_1  2021-07-24 06:47:43             476        Bf_1        476
# 476        Bf_2  2021-07-24 07:01:57             477        Bf_2        477
#
# [477 rows x 5 columns]

# %% [markdown]
# ### Run drift correction with LOESS smoothing

# %% [markdown]
# We can now correct our data for experimental drift.
#
# With the acore LOESS drift-correction function, a LOESS (locally estimated regression)
# smoother is applied separately to the features in the data to model slow temporal
# trends, and the resulting smooth trend is used to correct the data.
#
# Before the function estimation and correction, the data can filtered, to remove
# features that have too many missing values in the QC samples.

# %% [markdown]
# First, we can create a dictionary for our sample names, ordering them into groups, to make the upcoming function call easier.

# %%
column_list = list(df.columns.values)
sample_cols = []
qc_cols = []
for col in column_list:
    if col.startswith("AAA"):
        sample_cols.append(col)
    elif col.startswith("QC"):
        qc_cols.append(col)

# %% [markdown]
# Now, are sample column names are summarised in the sample_cols variable. Here is a preview of them:

# %%
sample_cols
# Out:
# ['AAA9485207',
#  'AAA9485216',
#  'AAA9485239',
#  'AAA9485258',
#  'AAA9485261',
#  'AAA9485274',
#  'AAA9485282',
#  'AAA9485295',
#  'AAA9485915',
#  'AAA9485917',
#  'AAA9485919',
#  'AAA9485921',
#  'AAA9485950',
#  'AAA9485953',
#  'AAA9485954',
#  'AAA9485967',
#  'AAA9485968',
#  'AAA9485969',
#  'AAA9485972',
#  'AAA9485973',
#  'AAA9485977',
#  'AAA9485981',
#  'AAA9485983',
#  'AAA9485989',
#  'AAA9486247',
#  'AAA9486248',
#  'AAA9486256',
#  'AAA9486260',
#  'AAA9486273',
#  'AAA9486279',
#  'AAA9486282',
#  'AAA9486283',
#  'AAA9486294',
#  'AAA9486295',
#  'AAA9487423',
#  'AAA9487435',
#  'AAA9487460',
#  'AAA9487467',
#  'AAA9487477',
#  'AAA9487603',
#  'AAA9487607',
#  'AAA9487621',
#  'AAA9487624',
#  'AAA9487626',
#  'AAA9487642',
#  'AAA9487667',
#  'AAA9487683',
#  'AAA9487684',
#  'AAA9487690',
#  'AAA9487695',
#  'AAA9487713',
#  'AAA9487717',
#  'AAA9487719',
#  'AAA9487746',
#  'AAA9487751',
#  'AAA9528251',
#  'AAA9528268',
#  'AAA9528270',
#  'AAA9528272',
#  'AAA9528279',
#  'AAA9528285',
#  'AAA9528291',
#  'AAA9528313',
#  'AAA9528321',
#  'AAA9528328',
#  'AAA9528346',
#  'AAA9528357',
#  'AAA9528371',
#  'AAA9528389',
#  'AAA9528396',
#  'AAA9528503',
#  'AAA9528509',
#  'AAA9528548',
#  'AAA9528559',
#  'AAA9528568',
#  'AAA9528723',
#  'AAA9528728',
#  'AAA9528730',
#  'AAA9528741',
#  'AAA9528750',
#  'AAA9528753',
#  'AAA9528771',
#  'AAA9528917',
#  'AAA9528919',
#  'AAA9528972',
#  'AAA9528973',
#  'AAA9528989',
#  'AAA9546613',
#  'AAA9546627',
#  'AAA9546638',
#  'AAA9546652',
#  'AAA9546655',
#  'AAA9546656',
#  'AAA9546686',
#  'AAA9546709',
#  'AAA9546715',
#  'AAA9546737',
#  'AAA9546740',
#  'AAA9546761',
#  'AAA9546762',
#  'AAA9546770',
#  'AAA9546791',
#  'AAA9546793',
#  'AAA9546930',
#  'AAA9546931',
#  'AAA9546932',
#  'AAA9546943',
#  'AAA9546950',
#  'AAA9546955',
#  'AAA9546974',
#  'AAA9547107',
#  'AAA9547115',
#  'AAA9547118',
#  'AAA9547119',
#  'AAA9547122',
#  'AAA9547163',
#  'AAA9547182',
#  'AAA9547185',
#  'AAA9547187',
#  'AAA9547502',
#  'AAA9547540',
#  'AAA9547541',
#  'AAA9547555',
#  'AAA9547571',
#  'AAA9547589',
#  'AAA9547591']

# %% [markdown]
# Our columns corresponding to QC data are saved in the qc_cols variable. Here is a preview of them:

# %%
qc_cols
# Out:
# ['QC_00',
#  'QC_01',
#  'QC_02',
#  'QC_03',
#  'QC_04',
#  'QC_05',
#  'QC_06',
#  'QC_07',
#  'QC_08',
#  'QC_09',
#  'QC_10',
#  'QC_11',
#  'QC_12',
#  'QC_13',
#  'QC_14',
#  'QC_15',
#  'QC_16',
#  'QC_17',
#  'QC_18',
#  'QC_19',
#  'QC_20',
#  'QC_21',
#  'QC_22',
#  'QC_23',
#  'QC_24',
#  'QC_25',
#  'QC_26',
#  'QC_27',
#  'QC_28',
#  'QC_29',
#  'QC_30',
#  'QC_31',
#  'QC_32',
#  'QC_33',
#  'QC_34',
#  'QC_35',
#  'QC_36',
#  'QC_37',
#  'QC_38',
#  'QC_39',
#  'QC_40',
#  'QC_41',
#  'QC_42',
#  'QC_43',
#  'QC_44']

# %% [markdown]
# Now we can run the drift correction, using the acore run_loess_drift_correction function.

# %%
corrected_df, correction_info = dc.run_loess_drift_correction(
    df,
    qc_cols,
    sample_cols,
    sample_order=sample_order,
    feature_name_col=None,
    filter_percent=0.5,
)

# %% [markdown]
# Explanation of the parameters chosen:
#  - feature_name_col = the name of the column containing feature names, if there is one.
#    This information is used for logging and showing outputs, it's not required for the
#   functioning of the method. Here, there is no feature name column available, so
#   "None" is used.
# - filter_percent =  the minimum percentage of values that must be present for this
#   feature to be retained. If the percentage of non-missing is below this, the feature   will be filtered out. If this parameter is set to "None", no filtering will be done.

# %% [markdown]
# Now we can inspect our results. First, the corrected output dataframe.

# %%
corrected_df
# Out:
#        Qidx  SOIidx   rtmed   start     end    mass        MaxInt  \
# 0         1       1  60.544  45.000  72.500  81.070   160,840.953
# 1         2       4 172.568 161.439 191.635  82.053    98,153.547
# 2         3       6 143.225 116.953 165.260  82.053   134,492.109
# 3         4       7 330.747 313.125 373.976  82.065    67,051.617
# 4         5       7 343.980 313.125 373.976  82.065    67,051.617
# ...     ...     ...     ...     ...     ...     ...           ...
# 2,539 2,540   2,363 290.896 290.000 312.500 892.654 3,486,662.000
# 2,540 2,541   2,363 299.617 290.000 312.500 892.654 3,486,662.000
# 2,541 2,542   2,364  54.789  50.000  67.500 892.739   179,925.600
# 2,542 2,543   2,365  54.782  50.000  67.500 894.755   488,985.200
# 2,544 2,545   2,367  54.821  50.000  67.500 896.770   843,227.000
#
#               formula             anot    AAA9485207  ...         QC_35  \
# 0             [C6H9]+         C6H8_M+H   161,110.713  ...   109,922.454
# 1           [C4H6N2]+       C4H5N2_M+H    75,743.388  ...    76,962.173
# 2           [C4H6N2]+       C4H5N2_M+H   103,137.428  ...   113,502.457
# 3            [C5H8N]+        C5H7N_M+H    41,174.282  ...    58,188.809
# 4            [C5H8N]+        C5H7N_M+H    17,595.444  ...    26,940.969
# ...               ...              ...           ...  ...           ...
# 2,539  [C48H94NO11S]+  C48H93NO11S_M+H 5,918,155.987  ... 3,663,099.159
# 2,540  [C48H94NO11S]+  C48H93NO11S_M+H   142,900.920  ...    67,344.264
# 2,541    [C57H98NO6]+   C57H94O6_M+NH4   135,396.243  ...   190,293.436
# 2,542   [C57H100NO6]+   C57H96O6_M+NH4   487,797.273  ...   505,918.267
# 2,544   [C57H102NO6]+   C57H98O6_M+NH4   814,104.831  ...   899,871.980
#
#               QC_36         QC_37         QC_38         QC_39         QC_40  \
# 0        93,885.248    75,609.337   102,461.940   329,509.578   194,995.095
# 1        77,569.699    68,760.786    81,682.503    73,086.323    76,144.336
# 2       118,034.167   116,442.905   115,917.014   111,245.665   121,089.586
# 3        55,827.062    58,839.479    58,490.680    59,257.009    47,274.697
# 4        22,985.921    21,799.139    21,208.793    27,569.233    26,395.354
# ...             ...           ...           ...           ...           ...
# 2,539 3,407,192.810 2,985,308.512 3,101,387.310 3,320,002.557 4,177,951.162
# 2,540    54,528.128   102,803.815    90,225.723    97,460.345    90,593.614
# 2,541   175,101.335    58,382.213   178,285.971    49,065.574   140,511.862
# 2,542   446,539.648   133,076.040   513,243.836   117,529.510   396,105.487
# 2,544   825,362.614   219,502.863   768,099.650   172,589.496   670,118.680
#
#               QC_41         QC_42         QC_43         QC_44
# 0       188,144.143   167,466.198   148,063.058   117,726.788
# 1        62,157.322    72,783.762    71,487.986    75,980.057
# 2       124,555.692   112,264.074   129,753.604   120,823.274
# 3        64,676.358    59,754.624    56,385.669    56,861.042
# 4        33,485.676    18,947.374    24,154.716    19,729.885
# ...             ...           ...           ...           ...
# 2,539 4,072,486.300 3,621,214.507 3,512,814.684 4,944,659.586
# 2,540    81,492.479    64,863.582    98,109.748    73,312.283
#          21675.38476562,  16033.86132812,  21695.74023438,  24277.67382812,
#          28411.1953125 ,  26573.94335938,  69722.09375   ,  21446.71875   ,
#          29022.80664062,  23445.98242188,  20964.00390625,  24669.5546875 ,
#          30190.25390625,  44812.25390625,  34488.625     ,  18152.20117188,
#          20419.8046875 ,  36131.0078125 ,  36577.53515625,  44349.40625   ,
#          18524.1875    ,  22687.7734375 ,  33303.6875    , 100284.6015625 ,
#          45113.78515625,  70072.671875  ,  54953.80078125,  50177.8359375 ,
#          57586.01171875,  66693.546875  ,  73603.171875  ,  79239.7578125 ,
#          82793.421875  ,  80197.7109375 ,  74642.390625  ,  96679.125     ,
#          88123.2109375 , 107308.46875   ,  93728.4296875 , 112787.5625    ,
#          93568.828125  , 124562.578125  , 118008.984375  , 125511.4140625 ,
#         124251.7734375 , 136760.484375  , 126815.7734375 , 120638.        ,
#         128232.84375   , 147434.171875  , 161396.        , 150885.796875  ,
#          29073.33398438,  34253.63671875,  25774.20507812,  30055.59375   ,
#          32262.68164062,  30580.20898438,  32329.05273438,  31555.74414062,
#          33427.6015625 ,  91476.8125    ,  58279.58203125,  60026.91015625,
#          57518.7890625 ,  61595.5078125 ,  58475.5390625 ]),
#  'status': 'corrected'}

# %% [markdown]
# ### Plot an example curve for one feature

# %% [markdown]
# We can also plot an example feature, to see how the values have changed
# and what the LOESS curve would look like for the data of this feature.

# %%
plot_loess_example_curve(
    df=df,
    feature_idx=300,
    sample_cols=sample_cols,
    qc_cols=qc_cols,
    sample_order=sample_order,
)

# %% [markdown]
# In this plot, we can see all of the data points of this feature, ordered by the
# injection time. The red points are our QC samples, so we can see whether there was any
# instrumental drift over time. The LOESS curve is also calculated, with the smoothing
# value alpha chosen with leave-one-out cross validation, just like in the
# run_drift_correction function.
#
# Alternative values for the smoothing parameter alpha can be tested by adding the
# argument "alpha" and choosing a value, just like in the example below.

# %%
plot_loess_example_curve(
    df=df,
    feature_idx=300,
    sample_cols=sample_cols,
    qc_cols=qc_cols,
    sample_order=sample_order,
    alpha=0.6,
)

# %% [markdown]
# ## 2. Common Principal Components Analysis-based drift correction

# %% [markdown]
# We can also use another method for correcting drift which is based on Common Principal
# Components Analysis (CPCA). This method is based on common principal components in
# defined groups of the data. It assumes that when calculating common principal
# components of QC samples, the drift contribution can be identified as the direction
# capturing maximum variance that simultaneously diagonalizes the covariance matrices of
# a set of classes.
#
# Therefore, the variability in the identified direction can be explained as caused by
# experimental drift and subtracted from all samples.
#
# Let's use different example data for demonstrating this method.

# %% [markdown]
# ### Load in data

# %%
# Load data
df = pd.read_csv(
    "../../example_data/DidacMauricio_hilic/DM_FIS2018_Hilic_pos_results2023_filled_imputed.csv",
    index_col=0,
)

# Define sample columns and qc columns
collist = list(df.columns.values)
sample_cols = []
qc_cols = []
for col in collist:
    if col.startswith("AAA"):
        sample_cols.append(col)
    elif col.startswith("QC"):
        qc_cols.append(col)
df
# Out:
#        Qidx  SOIidx   rtmed   start     end    mass        MaxInt  \
# 0         1       1  60.544  45.000  72.500  81.070   160,840.953
# 1         2       4 172.568 161.439 191.635  82.053    98,153.547
# 2         3       6 143.225 116.953 165.260  82.053   134,492.109
# 3         4       7 330.747 313.125 373.976  82.065    67,051.617
# 4         5       7 343.980 313.125 373.976  82.065    67,051.617
# ...     ...     ...     ...     ...     ...     ...           ...
# 2,539 2,540   2,363 290.896 290.000 312.500 892.654 3,486,662.000
# 2,540 2,541   2,363 299.617 290.000 312.500 892.654 3,486,662.000
# 2,541 2,542   2,364  54.789  50.000  67.500 892.739   179,925.600
# 2,542 2,543   2,365  54.782  50.000  67.500 894.755   488,985.200
# 2,544 2,545   2,367  54.821  50.000  67.500 896.770   843,227.000
#
#               formula             anot    AAA9485207  ...         QC_35  \
# 0             [C6H9]+         C6H8_M+H   279,488.531  ...   142,100.734
# 1           [C4H6N2]+       C4H5N2_M+H    73,170.344  ...    72,917.398
# 2           [C4H6N2]+       C4H5N2_M+H   106,222.969  ...   117,823.602
# 3            [C5H8N]+        C5H7N_M+H    40,187.371  ...    58,493.379
# 4            [C5H8N]+        C5H7N_M+H    16,231.437  ...    25,015.951
# ...               ...              ...           ...  ...           ...
# 2,539  [C48H94NO11S]+  C48H93NO11S_M+H 6,403,619.000  ... 4,217,977.000
# 2,540  [C48H94NO11S]+  C48H93NO11S_M+H   137,733.500  ...    66,690.800
# 2,541    [C57H98NO6]+   C57H94O6_M+NH4   130,200.000  ...   190,497.800
# 2,542   [C57H100NO6]+   C57H96O6_M+NH4   468,793.800  ...   523,346.000
# 2,544   [C57H102NO6]+   C57H98O6_M+NH4   821,122.200  ...   998,584.700
#
#               QC_36         QC_37         QC_38         QC_39         QC_40  \
# 0       129,631.148   110,443.422   157,871.062   535,311.375   334,133.656
# 1        73,738.812    65,597.875    78,216.859    70,257.375    73,489.242
# 2       122,279.500   120,513.508   119,803.422   114,791.906   124,753.789
# 3        55,851.680    58,560.121    57,886.605    58,293.699    46,211.445
# 4        21,309.277    20,180.580    19,609.604    25,462.301    24,354.287
# ...             ...           ...           ...           ...           ...
# 2,539 3,872,732.000 3,356,819.000 3,444,360.000 3,641,683.000 4,531,348.000
# 2,540    53,758.060   100,864.900    88,069.460    94,612.190    87,438.410
# 2,541   173,043.300    57,476.910   174,392.000    47,625.360   135,338.900
# 2,542   453,992.800   133,935.100   509,662.500   114,995.100   381,900.100
# 2,544   897,026.200   235,440.700   809,741.600   178,420.900   678,957.200
#
#               QC_41         QC_42         QC_43         QC_44
# 0       339,973.344   317,506.188   294,083.344   234,717.266
# 1        60,233.695    70,798.312    69,802.516    74,212.203
# 2       128,157.016   115,411.750   133,331.281   124,152.578
# 3        62,802.289    57,658.062    54,058.363    54,484.602
# 4        30,869.357    17,454.047    22,235.070    18,160.814
# ...             ...           ...           ...           ...
# 2,539 4,375,519.000 3,864,418.000 3,730,628.000 5,249,600.000
# 2,540    78,174.880    61,854.690    92,978.760    69,441.320
# 2,541   154,609.500   179,258.000   171,145.200   161,171.100
# 2,542   421,614.900   503,656.400   439,513.500   434,035.700
# 2,544   785,135.600   895,259.400   788,261.100   768,748.800
#
# [2287 rows x 486 columns]

# %% [markdown]
# Seeing as this method is based on calculating principal components, as with PCA, there
# must not be any missing data.
#
# We will therefore first calculate missingness (NAs).
#
# We need to check for missing values in both the sample columns and the QC columns.

# %%
if dc.check_missingness(df, sample_cols + qc_cols):
    print(
        "There are missing values. Consider imputing first, or use LOESS drift correction instead."
    )
else:
    print("\nThere is no missingness. We can proceed with the CPCA drift correction.")
# Out:
# There is no missingness. We can proceed with the CPCA drift correction.

# %% [markdown]
# ### Visualise non-corrected data
#
# Now that we know we can proceed, let's visualise our data before drift correction with
# a PCA.

# %%
pca_for_cpca_drift(
    df,
    sample_cols,  # list of col names, OR dict {group_name: [col names]}
    qc_cols,
    log_transform=True,
    title="PCA",
)

# %% [markdown]
# We see some clear indication of instrumental drift in the QC samples.

# %% [markdown]
# ### Run drift correction based on CPCA

# %%
df_corrected = dc.run_cpca_drift_correction(df, sample_cols, qc_cols, n_comps=1)

# %% [markdown]
# Let's plot the corrected data.

# %%
pca_for_cpca_drift(  # This function is defined in the beginning of this notebook.
    df_corrected,
    sample_cols,  # list of col names, OR dict {group_name: [col names]}
    qc_cols,
    log_transform=True,
    title="PCA",
)

# %% [markdown]
# There is some change, but still a significant amount of drift is clearly visible from
# the PCA plot.
#
# We can play around with the n_comps variable which decides the number of components.

# %%
df_corrected_2comps = dc.run_cpca_drift_correction(df, sample_cols, qc_cols, n_comps=2)

df_corrected_3comps = dc.run_cpca_drift_correction(df, sample_cols, qc_cols, n_comps=3)

df_corrected_4comps = dc.run_cpca_drift_correction(df, sample_cols, qc_cols, n_comps=4)

# %%
pca_for_cpca_drift(
    df_corrected_2comps,
    sample_cols,  # list of col names, OR dict {group_name: [col names]}
    qc_cols,
    log_transform=True,
    title="PCA with 2 components",
)

pca_for_cpca_drift(
    df_corrected_3comps,
    sample_cols,  # list of col names, OR dict {group_name: [col names]}
    qc_cols,
    log_transform=True,
    title="PCA with 3 components",
)

pca_for_cpca_drift(
    df_corrected_4comps,
    sample_cols,  # list of col names, OR dict {group_name: [col names]}
    qc_cols,
    log_transform=True,
    title="PCA with 4 components",
)

# %% [markdown]
# The correction methods with three and four components are already looking better.
# Let's calculate the centroids of the QC principal components and the distance of the
# QC points to them, to objectively decide which number of n_comps is most favourable.

# %%
print(
    f"1 component: {dc.cpca_centroid(df_corrected, sample_cols, qc_cols, log_transform=True)}"
)
print(
    f"2 components: {dc.cpca_centroid(df_corrected_2comps, sample_cols, qc_cols, log_transform=True)}"
)
print(
    f"3 components: {dc.cpca_centroid(df_corrected_3comps, sample_cols, qc_cols, log_transform=True)}"
)
print(
    f"4 components: {dc.cpca_centroid(df_corrected_4comps, sample_cols, qc_cols, log_transform=True)}"
)
# Out:
# 1 component: 6.659708733516719
# 2 components: 7.944507196572296
# 3 components: 1.8489928516323137
# 4 components: 2.251196575019231

# %% [markdown]
# According to this, the CPCA method with three principal components is most favourable
# in this case.
#
# We can go ahead and continue our metabolomics data analysis with this data set.

# %%
df_corrected_3comps
# Out:
#        Qidx  SOIidx   rtmed   start     end    mass        MaxInt  \
# 0         1       1  60.544  45.000  72.500  81.070   160,840.953
# 1         2       4 172.568 161.439 191.635  82.053    98,153.547
# 2         3       6 143.225 116.953 165.260  82.053   134,492.109
# 3         4       7 330.747 313.125 373.976  82.065    67,051.617
# 4         5       7 343.980 313.125 373.976  82.065    67,051.617
# ...     ...     ...     ...     ...     ...     ...           ...
# 2,539 2,540   2,363 290.896 290.000 312.500 892.654 3,486,662.000
# 2,540 2,541   2,363 299.617 290.000 312.500 892.654 3,486,662.000
# 2,541 2,542   2,364  54.789  50.000  67.500 892.739   179,925.600
# 2,542 2,543   2,365  54.782  50.000  67.500 894.755   488,985.200
# 2,544 2,545   2,367  54.821  50.000  67.500 896.770   843,227.000
#
#               formula             anot       Bf_1  ...         QC_35  \
# 0             [C6H9]+         C6H8_M+H 97,091.484  ...   134,201.378
# 1           [C4H6N2]+       C4H5N2_M+H  6,847.325  ...    76,488.701
# 2           [C4H6N2]+       C4H5N2_M+H  8,152.757  ...   120,466.910
# 3            [C5H8N]+        C5H7N_M+H  4,913.175  ...    60,590.816
# 4            [C5H8N]+        C5H7N_M+H  5,198.102  ...    26,734.785
# ...               ...              ...        ...  ...           ...
# 2,539  [C48H94NO11S]+  C48H93NO11S_M+H        NaN  ... 4,873,269.064
# 2,540  [C48H94NO11S]+  C48H93NO11S_M+H        NaN  ...    94,922.483
# 2,541    [C57H98NO6]+   C57H94O6_M+NH4        NaN  ...   209,302.985
# 2,542   [C57H100NO6]+   C57H96O6_M+NH4  3,947.676  ...   574,917.951
# 2,544   [C57H102NO6]+   C57H98O6_M+NH4 28,217.930  ... 1,090,133.527
#
#               QC_36         QC_37         QC_38         QC_39         QC_40  \
# 0       121,716.652   105,110.406   151,398.431   524,193.983   318,993.906
# 1        77,754.914    69,414.055    82,880.137    81,202.109    84,522.111
# 2       125,361.284   123,620.363   123,798.365   126,378.429   135,945.215
# 3        58,188.906    60,810.258    60,415.006    62,144.502    50,231.349
# 4        23,201.861    21,940.368    21,609.380    28,639.477    27,755.257
# ...             ...           ...           ...           ...           ...
# 2,539 4,638,220.136 4,191,502.020 4,344,389.643 4,777,019.908 5,587,889.118
# 2,540    86,176.900   135,391.411   124,035.180   125,231.550   117,029.993
# 2,541   195,053.795    81,244.594   200,912.672    90,310.425   175,457.154
# 2,542   515,026.068   200,761.134   585,874.266   256,080.712   513,082.085
# 2,544 1,006,327.653   356,490.079   949,873.745   460,919.647   939,820.835
#
#               QC_41         QC_42         QC_43         QC_44
# 0       322,126.443   301,912.641   275,656.649   215,208.092
# 1        70,822.062    80,115.299    79,188.791    84,404.918
# 2       138,438.511   124,387.851   142,043.838   133,753.800
# 3        66,830.331    61,294.845    57,809.475    58,451.701
# 4        34,336.715    20,564.553    25,500.161    21,621.256
# ...             ...           ...           ...           ...
# 2,539 5,344,841.278 4,772,819.371 4,580,556.612 6,134,909.597
# 2,540   107,022.501    90,008.901   120,231.160    96,677.520
# 2,541   191,280.421   212,727.546   202,758.257   194,838.649
# 2,542   539,560.564   610,192.128   539,008.118   541,233.603
# 2,544 1,017,289.233 1,103,739.770   981,474.638   978,352.995
#
# [2287 rows x 486 columns]
