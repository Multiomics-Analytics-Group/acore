# %% [markdown]
# # Metabolomics drift correction

# %% [markdown]
# Within-batch correction of metabolomics data.
# This script shows how to correct for instrumental drift based on pooled QC data samples.

# %% [markdown]
# ## 1. LOESS smoothing-based drift correction

# %% [markdown]
# ### Load in example data

# %%
#%pip install acore

# %%
import acore
from acore import drift_correction as dc

import pandas as pd
import os
import importlib

importlib.reload(acore)
# Out:
# <module 'acore' from '/Users/fcasc/Documents/03_CORE/acore/src/acore/__init__.py'>

# %% [markdown]
# ### Load in data

# %%
df = pd.read_excel("../../example_data/aradopsis_seedling_lipids/kehelpannala_AnArabidopsisLipid_seedling.xlsx")
sample_order = pd.read_csv("../../example_data/aradopsis_seedling_lipids/seedling_art_sample_order.csv")

# %%
df
# Out:
#      Unnamed: 0                Lipid species      Adduct       m/z  RT (min)  \
# 0             1    ADGGA 50:2; 16:0/16:0_18:2   [M+NH4]+ 1,024.797    18.141
# 1             2    ADGGA 50:3; 16:0/16:0_18:3   [M+NH4]+ 1,022.778    17.097
# 2             5  Cer-AP t34:1+O; t18:1/16:0+O     [M+H]+   570.508     9.596
# 3             6  Cer-AP t40:0+O; t18:0/22:0+O     [M+H]+   656.613    15.488
# 4             7  Cer-AP t40:1+O; t18:1/22:0+O     [M+H]+   654.607    14.716
# ..          ...                           ...        ...       ...       ...
# 332         363       TG 62:2; 24:0_18:1_20:1   [M+NH4]+ 1,016.953    23.249
# 333         364       TG 62:4; 26:0_18:2_18:2   [M+NH4]+ 1,012.935    22.827
# 334         365       TG 62:5; 26:0_18:2_18:3   [M+NH4]+ 1,010.910    22.655
# 335         366       TG 62:5; 26:1_18:2_18:2   [M+NH4]+ 1,010.908    22.580
# 336         367       TG 62:6; 26:0_18:3_18:3   [M+NH4]+ 1,008.913    22.508
#
#      Characteristic fragments 4  Characteristic fragments 5  \
# 0                       415.272                     337.273
# 1                       239.240                     313.276
# 2                       298.271                     262.258
# 3                       300.280                     264.262
# 4                       298.272                     262.252
# ..                          ...                         ...
# 332                     717.673                     689.643
# 333                     715.647                     599.497
# 334                         NaN                         NaN
# 335                         NaN                         NaN
# 336                         NaN                         NaN
#
#      Characteristic fragments 6  Characteristic fragments 7  \
# 0                       313.254                     239.236
# 1                       335.261                     415.268
# 2                       280.264                     534.490
# 3                       282.276                     620.588
# 4                       280.267                     316.283
# ..                          ...                         ...
# 332                     631.566                         NaN
# 333                         NaN                         NaN
# 334                         NaN                         NaN
# 335                         NaN                         NaN
# 336                         NaN                         NaN
#
#      Characteristic fragments 8  ...  Sd3-7  Sd3-8  Sd3-9  PBQC_Sd_1  \
# 0                           NaN  ...  0.012  0.019  0.021      0.008
# 1                           NaN  ...  0.011  0.023  0.007      0.007
# 2                       552.499  ...  0.404  0.381  0.320      0.126
# 3                       638.602  ...  0.233  0.215  0.246      0.071
# 4                       600.560  ...  2.631  2.664  2.097      0.724
# ..                          ...  ...    ...    ...    ...        ...
# 332                         NaN  ...  0.127  0.160  0.122      0.064
# 333                         NaN  ...  0.070  0.115  0.171      0.043
# 334                         NaN  ...  0.044  0.169  0.117      0.020
# 335                         NaN  ...  0.189  0.053  0.070      0.073
# 336                         NaN  ...  0.194  0.157  0.165      0.082
#
#      PBQC_Sd_2  PBQC_Sd_3  PBQC_Sd_4  PBQC_Sd_5  PBQC_Sd_6  PBQC_CV
# 0        0.007      0.006      0.013      0.010      0.007   29.973
# 1        0.008      0.006      0.006      0.007      0.005   12.833
# 2        0.114      0.128      0.110      0.106      0.111    8.022
# 3        0.070      0.071      0.064      0.070      0.061    6.112
# 4        0.874      0.835      0.830      0.923      0.787    8.303
# ..         ...        ...        ...        ...        ...      ...
# 332      0.071      0.011      0.070      0.067      0.056   40.767
# 333      0.040      0.053      0.032      0.050      0.054   18.542
# 334      0.092      0.020      0.017      0.059      0.032   75.269
# 335      0.075      0.079      0.054      0.019      0.086   38.244
# 336      0.074      0.065      0.063      0.058      0.052   16.744
#
# [337 rows x 44 columns]

# %% [markdown]
# We also have (artificial) data that has the order in which our samples were run. This information is crucial for the drift corrrection algorithm.

# %%
sample_order.sort_values("Sample ID")
# Out:
#     Unnamed: 0  File Name  Sample ID
# 24          24  PBQC_Sd_1          1
# 0            0      Sd1_1          2
# 1            1      Sd1_2          3
# 2            2      Sd1_3          4
# 3            3      Sd1_4          5
# 25          25  PBQC_Sd_2          6
# 4            4      Sd1_5          7
# 5            5      Sd1_6          8
# 6            6      Sd2_1          9
# 7            7      Sd2_2         10
# 8            8      Sd2_3         11
# 26          26  PBQC_Sd_3         12
# 9            9      Sd2_4         13
# 10          10      Sd2_5         14
# 11          11      Sd2_6         15
# 12          12      Sd2_7         16
# 13          13      Sd2_8         17
# 14          14      Sd2_9         18
# 27          27  PBQC_Sd_4         19
# 15          15      Sd3-1         20
# 16          16      Sd3-2         21
# 17          17      Sd3-3         22
# 18          18      Sd3-4         23
# 19          19      Sd3-5         24
# 28          28  PBQC_Sd_5         25
# 20          20      Sd3-6         26
# 21          21      Sd3-7         27
# 22          22      Sd3-8         28
# 23          23      Sd3-9         29
# 29          29  PBQC_Sd_6         30

# %% [markdown]
# ### Run drift correction with LOESS smoothing

# %% [markdown]
# We can now correct our data for experimental drift.
#
# With the acore LOESS drift-correction function, a LOESS (locally estimated regression) smoother is applied separately to the features in the data to model slow temporal trends, and the resulting smooth trend is used to correct the data.
#
# Before the function estimation and correction, the data can filtered, to remove features that have too many missing values in the QC samples.

# %%
# First, we can create a dictionary for our sample names, ordering them into groups, to make the upcoming function call easier.

data_groups = {
    "SD1": ['Sd1_1','Sd1_2', 'Sd1_3', 'Sd1_4', 'Sd1_5', 'Sd1_6'],
    "SD2": ['Sd2_1', 'Sd2_2', 'Sd2_3', 'Sd2_4', 'Sd2_5', 'Sd2_6', 'Sd2_7', 'Sd2_8', 'Sd2_9'],
    "SD3": ['Sd3-1', 'Sd3-2', 'Sd3-3', 'Sd3-4', 'Sd3-5', 'Sd3-6', 'Sd3-7', 'Sd3-8', 'Sd3-9'],
    "QC" : [ 'PBQC_Sd_1', 'PBQC_Sd_2', 'PBQC_Sd_3', 'PBQC_Sd_4', 'PBQC_Sd_5', 'PBQC_Sd_6']
}

# %%
# Separate groups
sample_cols = data_groups["SD1"] + data_groups["SD2"] + data_groups[ "SD3"]
qc_cols = data_groups["QC"]

# Create a sub-df consisting only of the interesting columns, omitting metadata.
df_dc = df[sample_cols + qc_cols]

# %% [markdown]
# Now we can run the drift correction.

# %%
corrected_df, correction_info = dc.run_drift_correction(
    df, 
    qc_cols, 
    sample_cols, 
    sample_order=sample_order, 
    feature_name_col=None,
    filter_percent=0.5, 
    print_logs=True
)

### Explanation of the parameters chosen
# - feature_name_col = the name of the column containing feature names, if there is one. 
#   This information is used for logging and showing outputs, it's not required for the functioning of the method.
#   Here, there is no feature name column available, so "None" is used.
# - filter_percent =  the minimum percentage of values that must be present for this feature to be retained. 
#   If the percentage of non-missing is below this, the feature will be filtered out.
#   If this parameter is set to "None", no filtering will be done.
# - print_logs = whether there should be an output for the logs of the function. Like verbose.
# Out:
# Corrected 0 with alpha 0.6.
# Corrected 1 with alpha 0.9999999999999999.
# Corrected 2 with alpha 0.9999999999999999.
# Corrected 3 with alpha 0.9999999999999999.
# Corrected 4 with alpha 0.9999999999999999.
# Corrected 5 with alpha 0.9999999999999999.
# Corrected 6 with alpha 0.6.
# Corrected 7 with alpha 0.9999999999999999.
# Corrected 8 with alpha 0.9999999999999999.
# Corrected 9 with alpha 0.9999999999999999.
# Corrected 10 with alpha 0.7999999999999999.
# Corrected 11 with alpha 0.9999999999999999.
# Corrected 12 with alpha 0.9999999999999999.
# Flagging feature 13 due to too high QC RSD. (Feature not skipped)
# RSD: 42.131018920330554
# Corrected 13 with alpha 0.9999999999999999.
# Flagging feature 14 due to too high QC RSD. (Feature not skipped)
# RSD: 81.76681618000576
# Corrected 14 with alpha 0.9999999999999999.
# Corrected 15 with alpha 0.7999999999999999.
# Corrected 16 with alpha 0.9999999999999999.
# Corrected 17 with alpha 0.6.
# Flagging feature 18 due to too high QC RSD. (Feature not skipped)
# RSD: 78.2238466951209
# Corrected 18 with alpha 0.9999999999999999.
# Corrected 19 with alpha 0.9999999999999999.
# Flagging feature 20 due to too high QC RSD. (Feature not skipped)
# RSD: 65.23951760224979
# Corrected 20 with alpha 0.9999999999999999.
# Flagging feature 21 due to too high QC RSD. (Feature not skipped)
# RSD: 34.37453347876388
# Corrected 21 with alpha 0.7999999999999999.
# Corrected 22 with alpha 0.9999999999999999.
# Corrected 23 with alpha 0.9999999999999999.
# Corrected 24 with alpha 0.9999999999999999.
# Corrected 25 with alpha 0.9999999999999999.
# Corrected 26 with alpha 0.7999999999999999.
# Corrected 27 with alpha 0.6.
# Corrected 28 with alpha 0.9999999999999999.
# Corrected 29 with alpha 0.9999999999999999.
# Corrected 30 with alpha 0.9999999999999999.
# Corrected 31 with alpha 0.7999999999999999.
# Corrected 32 with alpha 0.9999999999999999.
# Corrected 33 with alpha 0.6.
# Corrected 34 with alpha 0.9999999999999999.
# Flagging feature 35 due to too high QC RSD. (Feature not skipped)
# RSD: 53.0450152042146
# Corrected 35 with alpha 0.9999999999999999.
# Flagging feature 36 due to too high QC RSD. (Feature not skipped)
# RSD: 54.13576805980862
# Corrected 36 with alpha 0.9999999999999999.
# Corrected 37 with alpha 0.9999999999999999.
# Corrected 38 with alpha 0.9999999999999999.
# Corrected 39 with alpha 0.9999999999999999.
# Flagging feature 40 due to too high QC RSD. (Feature not skipped)
# RSD: 36.28795947762814
# Corrected 40 with alpha 0.9999999999999999.
# Corrected 41 with alpha 0.6.
# Corrected 42 with alpha 0.9999999999999999.
# Flagging feature 43 due to too high QC RSD. (Feature not skipped)
# RSD: 48.11883938486089
# Corrected 43 with alpha 0.9999999999999999.
# Corrected 44 with alpha 0.6.
# Corrected 45 with alpha 0.9999999999999999.
# Corrected 46 with alpha 0.9999999999999999.
# Corrected 47 with alpha 0.7999999999999999.
# Flagging feature 48 due to too high QC RSD. (Feature not skipped)
# RSD: 31.38703045437296
# Corrected 48 with alpha 0.9999999999999999.
# Corrected 49 with alpha 0.6.
# Corrected 50 with alpha 0.9999999999999999.
# Corrected 51 with alpha 0.6.
# Corrected 52 with alpha 0.7999999999999999.
# Corrected 53 with alpha 0.6.
# Corrected 54 with alpha 0.9999999999999999.
# Corrected 55 with alpha 0.9999999999999999.
# Corrected 56 with alpha 0.6.
# Corrected 57 with alpha 0.9999999999999999.
# Corrected 58 with alpha 0.9999999999999999.
# Corrected 59 with alpha 0.9999999999999999.
# Corrected 60 with alpha 0.9999999999999999.
# Corrected 61 with alpha 0.7999999999999999.
# Corrected 62 with alpha 0.9999999999999999.
# Flagging feature 63 due to too high QC RSD. (Feature not skipped)
# RSD: 33.945802740441515
# Corrected 63 with alpha 0.6.
# Corrected 64 with alpha 0.7999999999999999.
# Flagging feature 65 due to too high QC RSD. (Feature not skipped)
# RSD: 33.60441862992029
# Corrected 65 with alpha 0.7999999999999999.
# Corrected 66 with alpha 0.6.
# Corrected 67 with alpha 0.9999999999999999.
# Corrected 68 with alpha 0.7999999999999999.
# Corrected 69 with alpha 0.9999999999999999.
# Corrected 70 with alpha 0.9999999999999999.
# Corrected 71 with alpha 0.6.
# Corrected 72 with alpha 0.6.
# Flagging feature 73 due to too high QC RSD. (Feature not skipped)
# RSD: 69.05557102115236
# Corrected 73 with alpha 0.6.
# Corrected 74 with alpha 0.6.
# Corrected 75 with alpha 0.6.
# Corrected 76 with alpha 0.9999999999999999.
# Corrected 77 with alpha 0.6.
# Corrected 78 with alpha 0.9999999999999999.
# Corrected 79 with alpha 0.9999999999999999.
# Flagging feature 80 due to too high QC RSD. (Feature not skipped)
# RSD: 39.80521403661365
# Corrected 80 with alpha 0.9999999999999999.
# Corrected 81 with alpha 0.9999999999999999.
# Corrected 82 with alpha 0.6.
# Corrected 83 with alpha 0.9999999999999999.
# Corrected 84 with alpha 0.9999999999999999.
# Corrected 85 with alpha 0.9999999999999999.
# Corrected 86 with alpha 0.9999999999999999.
# Flagging feature 87 due to too high QC RSD. (Feature not skipped)
# RSD: 53.83411558517639
# Corrected 87 with alpha 0.6.
# Corrected 88 with alpha 0.9999999999999999.
# Corrected 89 with alpha 0.9999999999999999.
# Corrected 90 with alpha 0.9999999999999999.
# Flagging feature 91 due to too high QC RSD. (Feature not skipped)
# RSD: 30.64131129089042
# Corrected 91 with alpha 0.9999999999999999.
# Flagging feature 92 due to too high QC RSD. (Feature not skipped)
# RSD: 32.20363711566569
# Corrected 92 with alpha 0.9999999999999999.
# Corrected 93 with alpha 0.9999999999999999.
# Corrected 94 with alpha 0.9999999999999999.
# Flagging feature 95 due to too high QC RSD. (Feature not skipped)
# RSD: 30.810508373619886
# Corrected 95 with alpha 0.9999999999999999.
# Flagging feature 96 due to too high QC RSD. (Feature not skipped)
# RSD: 59.75056760886328
# Corrected 96 with alpha 0.9999999999999999.
# Corrected 97 with alpha 0.9999999999999999.
# Corrected 98 with alpha 0.9999999999999999.
# Corrected 99 with alpha 0.6.
# Corrected 100 with alpha 0.9999999999999999.
# Corrected 101 with alpha 0.9999999999999999.
# Corrected 102 with alpha 0.9999999999999999.
# Corrected 103 with alpha 0.9999999999999999.
# Corrected 104 with alpha 0.6.
# Corrected 105 with alpha 0.9999999999999999.
# Corrected 106 with alpha 0.9999999999999999.
# Flagging feature 107 due to too high QC RSD. (Feature not skipped)
# RSD: 44.49123833354943
# Corrected 107 with alpha 0.6.
# Corrected 108 with alpha 0.9999999999999999.
# Corrected 109 with alpha 0.9999999999999999.
# Corrected 110 with alpha 0.9999999999999999.
# Corrected 111 with alpha 0.9999999999999999.
# Corrected 112 with alpha 0.9999999999999999.
# Corrected 113 with alpha 0.6.
# Corrected 114 with alpha 0.9999999999999999.
# Corrected 115 with alpha 0.9999999999999999.
# Corrected 116 with alpha 0.9999999999999999.
# Corrected 117 with alpha 0.9999999999999999.
# Corrected 118 with alpha 0.6.
# Flagging feature 119 due to too high QC RSD. (Feature not skipped)
# RSD: 53.337458868826026
# Corrected 119 with alpha 0.9999999999999999.
# Corrected 120 with alpha 0.7999999999999999.
# Corrected 121 with alpha 0.9999999999999999.
# Corrected 122 with alpha 0.9999999999999999.
# Corrected 123 with alpha 0.9999999999999999.
# Corrected 124 with alpha 0.9999999999999999.
# Corrected 125 with alpha 0.9999999999999999.
# Corrected 126 with alpha 0.9999999999999999.
# Corrected 127 with alpha 0.9999999999999999.
# Corrected 128 with alpha 0.6.
# Corrected 129 with alpha 0.9999999999999999.
# Corrected 130 with alpha 0.9999999999999999.
# Corrected 131 with alpha 0.7999999999999999.
# Corrected 132 with alpha 0.9999999999999999.
# Corrected 133 with alpha 0.6.
# Corrected 134 with alpha 0.9999999999999999.
# Corrected 135 with alpha 0.9999999999999999.
# Corrected 136 with alpha 0.9999999999999999.
# Corrected 137 with alpha 0.9999999999999999.
# Corrected 138 with alpha 0.6.
# Corrected 139 with alpha 0.6.
# Corrected 140 with alpha 0.9999999999999999.
# Corrected 141 with alpha 0.9999999999999999.
# Corrected 142 with alpha 0.9999999999999999.
# Corrected 143 with alpha 0.9999999999999999.
# Corrected 144 with alpha 0.9999999999999999.
# Corrected 145 with alpha 0.9999999999999999.
# Corrected 146 with alpha 0.9999999999999999.
# Corrected 147 with alpha 0.9999999999999999.
# Corrected 148 with alpha 0.6.
# Corrected 149 with alpha 0.9999999999999999.
# Corrected 150 with alpha 0.9999999999999999.
# Corrected 151 with alpha 0.6.
# Corrected 152 with alpha 0.6.
# Corrected 153 with alpha 0.9999999999999999.
# Corrected 154 with alpha 0.9999999999999999.
# Corrected 155 with alpha 0.6.
# Corrected 156 with alpha 0.9999999999999999.
# Corrected 157 with alpha 0.9999999999999999.
# Corrected 158 with alpha 0.9999999999999999.
# Corrected 159 with alpha 0.9999999999999999.
# Corrected 160 with alpha 0.9999999999999999.
# Corrected 161 with alpha 0.9999999999999999.
# Corrected 162 with alpha 0.6.
# Corrected 163 with alpha 0.6.
# Corrected 164 with alpha 0.6.
# Corrected 165 with alpha 0.9999999999999999.
# Corrected 166 with alpha 0.9999999999999999.
# Corrected 167 with alpha 0.6.
# Corrected 168 with alpha 0.9999999999999999.
# Corrected 169 with alpha 0.6.
# Corrected 170 with alpha 0.6.
# Corrected 171 with alpha 0.9999999999999999.
# Corrected 172 with alpha 0.9999999999999999.
# Corrected 173 with alpha 0.6.
# Corrected 174 with alpha 0.6.
# Corrected 175 with alpha 0.9999999999999999.
# Corrected 176 with alpha 0.9999999999999999.
# Corrected 177 with alpha 0.9999999999999999.
# Flagging feature 178 due to too high QC RSD. (Feature not skipped)
# RSD: 34.784650339848824
# Corrected 178 with alpha 0.6.
# Corrected 179 with alpha 0.7999999999999999.
# Corrected 180 with alpha 0.7999999999999999.
# Corrected 181 with alpha 0.9999999999999999.
# Corrected 182 with alpha 0.9999999999999999.
# Corrected 183 with alpha 0.9999999999999999.
# Corrected 184 with alpha 0.6.
# Corrected 185 with alpha 0.9999999999999999.
# Corrected 186 with alpha 0.6.
# Corrected 187 with alpha 0.9999999999999999.
# Corrected 188 with alpha 0.6.
# Corrected 189 with alpha 0.7999999999999999.
# Corrected 190 with alpha 0.9999999999999999.
# Corrected 191 with alpha 0.6.
# Flagging feature 192 due to too high QC RSD. (Feature not skipped)
# RSD: 33.009721421858075
# Corrected 192 with alpha 0.7999999999999999.
# Corrected 193 with alpha 0.7999999999999999.
# Corrected 194 with alpha 0.9999999999999999.
# Corrected 195 with alpha 0.9999999999999999.
# Corrected 196 with alpha 0.9999999999999999.
# Corrected 197 with alpha 0.9999999999999999.
# Corrected 198 with alpha 0.7999999999999999.
# Corrected 199 with alpha 0.9999999999999999.
# Flagging feature 200 due to too high QC RSD. (Feature not skipped)
# RSD: 32.931697771711335
# Corrected 200 with alpha 0.9999999999999999.
# Corrected 201 with alpha 0.6.
# Corrected 202 with alpha 0.9999999999999999.
# Corrected 203 with alpha 0.9999999999999999.
# Corrected 204 with alpha 0.7999999999999999.
# Corrected 205 with alpha 0.9999999999999999.
# Corrected 206 with alpha 0.9999999999999999.
# Corrected 207 with alpha 0.9999999999999999.
# Flagging feature 208 due to too high QC RSD. (Feature not skipped)
# RSD: 51.726339130804355
# Corrected 208 with alpha 0.9999999999999999.
# Flagging feature 209 due to too high QC RSD. (Feature not skipped)
# RSD: 92.58635600318952
# Corrected 209 with alpha 0.7999999999999999.
# Corrected 210 with alpha 0.6.
# Corrected 211 with alpha 0.9999999999999999.
# Corrected 212 with alpha 0.9999999999999999.
# Corrected 213 with alpha 0.7999999999999999.
# Corrected 214 with alpha 0.7999999999999999.
# Corrected 215 with alpha 0.9999999999999999.
# Corrected 216 with alpha 0.7999999999999999.
# Corrected 217 with alpha 0.9999999999999999.
# Corrected 218 with alpha 0.9999999999999999.
# Corrected 219 with alpha 0.9999999999999999.
# Corrected 220 with alpha 0.6.
# Corrected 221 with alpha 0.9999999999999999.
# Corrected 222 with alpha 0.9999999999999999.
# Corrected 223 with alpha 0.7999999999999999.
# Corrected 224 with alpha 0.6.
# Corrected 225 with alpha 0.7999999999999999.
# Flagging feature 226 due to too high QC RSD. (Feature not skipped)
# RSD: 36.147438107132714
# Corrected 226 with alpha 0.9999999999999999.
# Corrected 227 with alpha 0.9999999999999999.
# Corrected 228 with alpha 0.6.
# Flagging feature 229 due to too high QC RSD. (Feature not skipped)
# RSD: 39.55473587962512
# Corrected 229 with alpha 0.6.
# Corrected 230 with alpha 0.9999999999999999.
# Corrected 231 with alpha 0.9999999999999999.
# Corrected 232 with alpha 0.6.
# Corrected 233 with alpha 0.9999999999999999.
# Corrected 234 with alpha 0.9999999999999999.
# Corrected 235 with alpha 0.9999999999999999.
# Flagging feature 236 due to too high QC RSD. (Feature not skipped)
# RSD: 70.24380600364138
# Corrected 236 with alpha 0.9999999999999999.
# Flagging feature 237 due to too high QC RSD. (Feature not skipped)
# RSD: 36.39857766352983
# Corrected 237 with alpha 0.6.
# Flagging feature 238 due to too high QC RSD. (Feature not skipped)
# RSD: 38.699704519483554
# Corrected 238 with alpha 0.6.
# Corrected 239 with alpha 0.9999999999999999.
# Corrected 240 with alpha 0.7999999999999999.
# Corrected 241 with alpha 0.9999999999999999.
# Flagging feature 242 due to too high QC RSD. (Feature not skipped)
# RSD: 30.39408088561171
# Corrected 242 with alpha 0.9999999999999999.
# Corrected 243 with alpha 0.9999999999999999.
# Corrected 244 with alpha 0.6.
# Corrected 245 with alpha 0.6.
# Corrected 246 with alpha 0.9999999999999999.
# Corrected 247 with alpha 0.7999999999999999.
# Corrected 248 with alpha 0.6.
# Corrected 249 with alpha 0.7999999999999999.
# Corrected 250 with alpha 0.7999999999999999.
# Corrected 251 with alpha 0.9999999999999999.
# Corrected 252 with alpha 0.9999999999999999.
# Corrected 253 with alpha 0.9999999999999999.
# Corrected 254 with alpha 0.6.
# Flagging feature 255 due to too high QC RSD. (Feature not skipped)
# RSD: 74.24531005301974
# Corrected 255 with alpha 0.9999999999999999.
# Corrected 256 with alpha 0.6.
# Corrected 257 with alpha 0.7999999999999999.
# Flagging feature 258 due to too high QC RSD. (Feature not skipped)
# RSD: 34.730557608903965
# Corrected 258 with alpha 0.9999999999999999.
# Flagging feature 259 due to too high QC RSD. (Feature not skipped)
# RSD: 31.3003615099971
# Corrected 259 with alpha 0.6.
# Corrected 260 with alpha 0.9999999999999999.
# Flagging feature 261 due to too high QC RSD. (Feature not skipped)
# RSD: 34.4969500036632
# Corrected 261 with alpha 0.6.
# Corrected 262 with alpha 0.9999999999999999.
# Flagging feature 263 due to too high QC RSD. (Feature not skipped)
# RSD: 45.73517842060523
# Corrected 263 with alpha 0.9999999999999999.
# Corrected 264 with alpha 0.9999999999999999.
# Flagging feature 265 due to too high QC RSD. (Feature not skipped)
# RSD: 47.506802534256884
# Corrected 265 with alpha 0.9999999999999999.
# Corrected 266 with alpha 0.9999999999999999.
# Corrected 267 with alpha 0.9999999999999999.
# Corrected 268 with alpha 0.6.
# Corrected 269 with alpha 0.9999999999999999.
# Corrected 270 with alpha 0.9999999999999999.
# Corrected 271 with alpha 0.9999999999999999.
# Corrected 272 with alpha 0.9999999999999999.
# Corrected 273 with alpha 0.9999999999999999.
# Corrected 274 with alpha 0.6.
# Flagging feature 275 due to too high QC RSD. (Feature not skipped)
# RSD: 39.372342931107426
# Corrected 275 with alpha 0.9999999999999999.
# Flagging feature 276 due to too high QC RSD. (Feature not skipped)
# RSD: 35.4670878160221
# Corrected 276 with alpha 0.6.
# Corrected 277 with alpha 0.7999999999999999.
# Corrected 278 with alpha 0.9999999999999999.
# Corrected 279 with alpha 0.9999999999999999.
# Corrected 280 with alpha 0.7999999999999999.
# Corrected 281 with alpha 0.9999999999999999.
# Corrected 282 with alpha 0.7999999999999999.
# Corrected 283 with alpha 0.6.
# Flagging feature 284 due to too high QC RSD. (Feature not skipped)
# RSD: 42.914331218962154
# Corrected 284 with alpha 0.9999999999999999.
# Corrected 285 with alpha 0.9999999999999999.
# Corrected 286 with alpha 0.9999999999999999.
# Flagging feature 287 due to too high QC RSD. (Feature not skipped)
# RSD: 30.674957662121763
# Corrected 287 with alpha 0.9999999999999999.
# Flagging feature 288 due to too high QC RSD. (Feature not skipped)
# RSD: 30.758228451237493
# Corrected 288 with alpha 0.9999999999999999.
# Corrected 289 with alpha 0.9999999999999999.
# Flagging feature 290 due to too high QC RSD. (Feature not skipped)
# RSD: 31.181828179995197
# Corrected 290 with alpha 0.9999999999999999.
# Flagging feature 291 due to too high QC RSD. (Feature not skipped)
# RSD: 38.85122051062108
# Corrected 291 with alpha 0.9999999999999999.
# Corrected 292 with alpha 0.7999999999999999.
# Corrected 293 with alpha 0.9999999999999999.
# Corrected 294 with alpha 0.7999999999999999.
# Corrected 295 with alpha 0.6.
# Corrected 296 with alpha 0.7999999999999999.
# Corrected 297 with alpha 0.9999999999999999.
# Corrected 298 with alpha 0.6.
# Corrected 299 with alpha 0.9999999999999999.
# Corrected 300 with alpha 0.9999999999999999.
# Flagging feature 301 due to too high QC RSD. (Feature not skipped)
# RSD: 51.70990483959699
# Corrected 301 with alpha 0.9999999999999999.
# Flagging feature 302 due to too high QC RSD. (Feature not skipped)
# RSD: 35.831980549170225
# Corrected 302 with alpha 0.9999999999999999.
# Flagging feature 303 due to too high QC RSD. (Feature not skipped)
# RSD: 42.108485444423465
# Corrected 303 with alpha 0.9999999999999999.
# Flagging feature 304 due to too high QC RSD. (Feature not skipped)
# RSD: 55.79960003759222
# Corrected 304 with alpha 0.7999999999999999.
# Flagging feature 305 due to too high QC RSD. (Feature not skipped)
# RSD: 43.77135397480721
# Corrected 305 with alpha 0.9999999999999999.
# Flagging feature 306 due to too high QC RSD. (Feature not skipped)
# RSD: 36.41280045620563
# Corrected 306 with alpha 0.9999999999999999.
# Corrected 307 with alpha 0.7999999999999999.
# Flagging feature 308 due to too high QC RSD. (Feature not skipped)
# RSD: 45.162758603005905
# Corrected 308 with alpha 0.9999999999999999.
# Flagging feature 309 due to too high QC RSD. (Feature not skipped)
# RSD: 34.77700834128077
# Corrected 309 with alpha 0.9999999999999999.
# Corrected 310 with alpha 0.9999999999999999.
# Flagging feature 311 due to too high QC RSD. (Feature not skipped)
# RSD: 33.048327934285766
# Corrected 311 with alpha 0.9999999999999999.
# Flagging feature 312 due to too high QC RSD. (Feature not skipped)
# RSD: 38.94846120059257
# Corrected 312 with alpha 0.9999999999999999.
# Corrected 313 with alpha 0.6.
# Corrected 314 with alpha 0.9999999999999999.
# Corrected 315 with alpha 0.7999999999999999.
# Corrected 316 with alpha 0.6.
# Corrected 317 with alpha 0.9999999999999999.
# Corrected 318 with alpha 0.9999999999999999.
# Corrected 319 with alpha 0.9999999999999999.
# Corrected 320 with alpha 0.9999999999999999.
# Flagging feature 321 due to too high QC RSD. (Feature not skipped)
# RSD: 32.05229097438002
# Corrected 321 with alpha 0.9999999999999999.
# Corrected 322 with alpha 0.9999999999999999.
# Flagging feature 323 due to too high QC RSD. (Feature not skipped)
# RSD: 30.717161482205523
# Corrected 323 with alpha 0.9999999999999999.
# Corrected 324 with alpha 0.9999999999999999.
# Flagging feature 325 due to too high QC RSD. (Feature not skipped)
# RSD: 38.07231023897996
# Corrected 325 with alpha 0.9999999999999999.
# Flagging feature 326 due to too high QC RSD. (Feature not skipped)
# RSD: 36.74526969589453
# Corrected 326 with alpha 0.9999999999999999.
# Corrected 327 with alpha 0.6.
# Corrected 328 with alpha 0.6.
# Corrected 329 with alpha 0.9999999999999999.
# Corrected 330 with alpha 0.6.
# Corrected 331 with alpha 0.6.
# Flagging feature 332 due to too high QC RSD. (Feature not skipped)
# RSD: 37.21492421599607
# Corrected 332 with alpha 0.9999999999999999.
# Corrected 333 with alpha 0.9999999999999999.
# Flagging feature 334 due to too high QC RSD. (Feature not skipped)
# RSD: 68.71084276253072
# Corrected 334 with alpha 0.9999999999999999.
# Flagging feature 335 due to too high QC RSD. (Feature not skipped)
# RSD: 34.911963842127854
# Corrected 335 with alpha 0.9999999999999999.
# Corrected 336 with alpha 0.6.
#
# All done. For further information on the corrected values, check the second returned object. Also reordered rows!

# %% [markdown]
# Now we can inspect our results. First, the corrected output dataframe.

# %%
corrected_df
# Out:
#      Unnamed: 0                Lipid species      Adduct       m/z  RT (min)  \
# 0             1    ADGGA 50:2; 16:0/16:0_18:2   [M+NH4]+ 1,024.797    18.141
# 1             2    ADGGA 50:3; 16:0/16:0_18:3   [M+NH4]+ 1,022.778    17.097
# 2             5  Cer-AP t34:1+O; t18:1/16:0+O     [M+H]+   570.508     9.596
# 3             6  Cer-AP t40:0+O; t18:0/22:0+O     [M+H]+   656.613    15.488
# 4             7  Cer-AP t40:1+O; t18:1/22:0+O     [M+H]+   654.607    14.716
# ..          ...                           ...        ...       ...       ...
# 332         363       TG 62:2; 24:0_18:1_20:1   [M+NH4]+ 1,016.953    23.249
# 333         364       TG 62:4; 26:0_18:2_18:2   [M+NH4]+ 1,012.935    22.827
# 334         365       TG 62:5; 26:0_18:2_18:3   [M+NH4]+ 1,010.910    22.655
# 335         366       TG 62:5; 26:1_18:2_18:2   [M+NH4]+ 1,010.908    22.580
# 336         367       TG 62:6; 26:0_18:3_18:3   [M+NH4]+ 1,008.913    22.508
#
#      Characteristic fragments 4  Characteristic fragments 5  \
# 0                       415.272                     337.273
# 1                       239.240                     313.276
# 2                       298.271                     262.258
# 3                       300.280                     264.262
# 4                       298.272                     262.252
# ..                          ...                         ...
# 332                     717.673                     689.643
# 333                     715.647                     599.497
# 334                         NaN                         NaN
# 335                         NaN                         NaN
# 336                         NaN                         NaN
#
#      Characteristic fragments 6  Characteristic fragments 7  \
# 0                       313.254                     239.236
# 1                       335.261                     415.268
# 2                       280.264                     534.490
# 3                       282.276                     620.588
# 4                       280.267                     316.283
# ..                          ...                         ...
# 332                     631.566                         NaN
# 333                         NaN                         NaN
# 334                         NaN                         NaN
# 335                         NaN                         NaN
# 336                         NaN                         NaN
#
#      Characteristic fragments 8  ...  Sd3-8  Sd3-9  PBQC_Sd_1  PBQC_Sd_2  \
# 0                           NaN  ...  0.018  0.022      0.007      0.007
# 1                           NaN  ...  0.026  0.008      0.006      0.007
# 2                       552.499  ...  0.398  0.336      0.114      0.106
# 3                       638.602  ...  0.234  0.269      0.070      0.069
# 4                       600.560  ...  2.647  2.086      0.779      0.907
# ..                          ...  ...    ...    ...        ...        ...
# 332                         NaN  ...  0.163  0.122      0.068      0.084
# 333                         NaN  ...  0.107  0.157      0.045      0.043
# 334                         NaN  ...  0.115  0.078      0.011      0.055
# 335                         NaN  ...  0.067  0.089      0.068      0.075
# 336                         NaN  ...  0.187  0.199      0.064      0.064
#
#      PBQC_Sd_3  PBQC_Sd_4  PBQC_Sd_5  PBQC_Sd_6  PBQC_CV  TempName
# 0        0.007      0.007      0.007      0.007   29.973         0
# 1        0.006      0.006      0.008      0.006   12.833         1
# 2        0.122      0.108      0.108      0.117    8.022         2
# 3        0.072      0.066      0.075      0.067    6.112         3
# 4        0.831      0.811      0.911      0.784    8.303         4
# ..         ...        ...        ...        ...      ...       ...
# 332      0.014      0.088      0.073      0.056   40.767       332
# 333      0.057      0.033      0.048      0.049   18.542       333
# 334      0.013      0.012      0.042      0.021   75.269       334
# 335      0.088      0.069      0.025      0.110   38.244       335
# 336      0.064      0.064      0.064      0.064   16.744       336
#
# [337 rows x 45 columns]

# %%
df
# Out:
#      Unnamed: 0                Lipid species      Adduct       m/z  RT (min)  \
# 0             1    ADGGA 50:2; 16:0/16:0_18:2   [M+NH4]+ 1,024.797    18.141
# 1             2    ADGGA 50:3; 16:0/16:0_18:3   [M+NH4]+ 1,022.778    17.097
# 2             5  Cer-AP t34:1+O; t18:1/16:0+O     [M+H]+   570.508     9.596
# 3             6  Cer-AP t40:0+O; t18:0/22:0+O     [M+H]+   656.613    15.488
# 4             7  Cer-AP t40:1+O; t18:1/22:0+O     [M+H]+   654.607    14.716
# ..          ...                           ...        ...       ...       ...
# 332         363       TG 62:2; 24:0_18:1_20:1   [M+NH4]+ 1,016.953    23.249
# 333         364       TG 62:4; 26:0_18:2_18:2   [M+NH4]+ 1,012.935    22.827
# 334         365       TG 62:5; 26:0_18:2_18:3   [M+NH4]+ 1,010.910    22.655
# 335         366       TG 62:5; 26:1_18:2_18:2   [M+NH4]+ 1,010.908    22.580
# 336         367       TG 62:6; 26:0_18:3_18:3   [M+NH4]+ 1,008.913    22.508
#
#      Characteristic fragments 4  Characteristic fragments 5  \
# 0                       415.272                     337.273
# 1                       239.240                     313.276
# 2                       298.271                     262.258
# 3                       300.280                     264.262
# 4                       298.272                     262.252
# ..                          ...                         ...
# 332                     717.673                     689.643
# 333                     715.647                     599.497
# 334                         NaN                         NaN
# 335                         NaN                         NaN
# 336                         NaN                         NaN
#
#      Characteristic fragments 6  Characteristic fragments 7  \
# 0                       313.254                     239.236
# 1                       335.261                     415.268
# 2                       280.264                     534.490
# 3                       282.276                     620.588
# 4                       280.267                     316.283
# ..                          ...                         ...
# 332                     631.566                         NaN
# 333                         NaN                         NaN
# 334                         NaN                         NaN
# 335                         NaN                         NaN
# 336                         NaN                         NaN
#
#      Characteristic fragments 8  ...  Sd3-7  Sd3-8  Sd3-9  PBQC_Sd_1  \
# 0                           NaN  ...  0.012  0.019  0.021      0.008
# 1                           NaN  ...  0.011  0.023  0.007      0.007
# 2                       552.499  ...  0.404  0.381  0.320      0.126
# 3                       638.602  ...  0.233  0.215  0.246      0.071
# 4                       600.560  ...  2.631  2.664  2.097      0.724
# ..                          ...  ...    ...    ...    ...        ...
# 332                         NaN  ...  0.127  0.160  0.122      0.064
# 333                         NaN  ...  0.070  0.115  0.171      0.043
# 334                         NaN  ...  0.044  0.169  0.117      0.020
# 335                         NaN  ...  0.189  0.053  0.070      0.073
# 336                         NaN  ...  0.194  0.157  0.165      0.082
#
#      PBQC_Sd_2  PBQC_Sd_3  PBQC_Sd_4  PBQC_Sd_5  PBQC_Sd_6  PBQC_CV
# 0        0.007      0.006      0.013      0.010      0.007   29.973
# 1        0.008      0.006      0.006      0.007      0.005   12.833
# 2        0.114      0.128      0.110      0.106      0.111    8.022
# 3        0.070      0.071      0.064      0.070      0.061    6.112
# 4        0.874      0.835      0.830      0.923      0.787    8.303
# ..         ...        ...        ...        ...        ...      ...
# 332      0.071      0.011      0.070      0.067      0.056   40.767
# 333      0.040      0.053      0.032      0.050      0.054   18.542
# 334      0.092      0.020      0.017      0.059      0.032   75.269
# 335      0.075      0.079      0.054      0.019      0.086   38.244
# 336      0.074      0.065      0.063      0.058      0.052   16.744
#
# [337 rows x 44 columns]

# %% [markdown]
# We can also look further into the correction_info object, to see the parameters that were chosen for each feature.
#
# For example, let's check the parameters used for the 200th feature.

# %%
correction_info[200]
# Out:
# {'alpha': np.float64(0.9999999999999999),
#  'drift_curve': [0.11006544927415765,
#   0.10902530439341297,
#   0.10803676752624497,
#   0.10708091749354393,
#   0.10519159321510337,
#   0.10422027661114426,
#   0.10320596212521285,
#   0.10212972857819934,
#   0.10097265479099393,
#   0.09833775289421522,
#   0.09680678911430461,
#   0.09508871375352752,
#   0.09314931232065644,
#   0.09095437032446389,
#   0.08846967327372238,
#   0.08250944644837123,
#   0.07905723011943926,
#   0.07536188562731365,
#   0.07148094090889955,
#   0.06747192390110208,
#   0.05929978476497768,
#   0.05525171851046103,
#   0.05130569171418163,
#   0.04751923231304461,
#   0.1111761233475889,
#   0.1061388331162,
#   0.0997158195844868,
#   0.08566100667720437,
#   0.0633923625408264,
#   0.04394986824395513],
#  'y_qc': [0.1097, 0.10574, 0.105218, 0.086961, 0.08665, 0.026189],
#  'x_qc': [1, 6, 12, 19, 25, 30],
#  'rsd_qc': np.float64(32.931697771711335),
#  'median': np.float64(0.0960895),
#  'y_all': array([0.78902715, 1.1869441 , 0.86874449, 0.62837778, 0.8779646 ,
#         0.87614352, 0.36781272, 0.29507011, 0.43382031, 0.38864945,
#         0.441361  , 0.45547099, 0.3870404 , 0.38544792, 0.41446914,
#         0.20661224, 0.18591558, 0.03261034, 0.137875  , 0.12826087,
#         0.04698007, 0.14854448, 0.26244211, 0.21437829, 0.1097    ,
#         0.10574   , 0.105218  , 0.086961  , 0.08665   , 0.026189  ]),
#  'status': 'corrected'}

# %% [markdown]
# ### Plot an example curve for one feature

# %% [markdown]
# We can also plot an example feature, to see how the values have changed and what the LOESS curve would look like for the data of this feature.

# %%
dc.loess_drift_correction.loess_example_curve(
    df=df,
    feature_idx=5,
    sample_cols=sample_cols,
    qc_cols=qc_cols,
    sample_order=sample_order
)

# %% [markdown]
# In this plot, we can see all of the data points of this feature, ordered by the injection time. The red points are our QC samples, so we can see whether there was any instrumental drift over time. The LOESS curve is also calculated, with the smoothing value alpha chosen with leave-one-out cross validation, just like in the run_drift_correction function.
#
# Alternative values for the smoothing parameter alpha can be tested by adding the argument "alpha" and choosing a value, just like in the example below.

# %%
dc.loess_drift_correction.loess_example_curve(
    df=df,
    feature_idx=5,
    sample_cols=sample_cols,
    qc_cols=qc_cols,
    sample_order=sample_order,
    alpha=0.6
)

# %% [markdown]
# ## 2. Common Principal Components Analysis-based drift correction

# %% [markdown]
# We can also use another method for correcting drift which is based on Common Principal Components Analysis (CPCA).
# This method is based on common principal components in defined groups of the data. It assumes that when calculating common principal components of QC samples, the drift contribution can be identified as the direction capturing maximum variance that simultaneously diagonalizes the covariance matrices of a set of classes.
#
# Therefore, the variability in the identified direction can be explained as caused by experimental drift and subtracted from all samples.
#
# Let's use different example data for demonstrating this method.

# %% [markdown]
# ### Load in data

# %%
# Load data
df = pd.read_csv("../../example_data/DidacMauricio_hilic/DM_FIS2018_Hilic_pos_results2023_filled_imputed.csv")

# Define sample columns and qc columns
collist = list(df.columns.values)
sample_cols = []
qc_cols = []
for col in collist:
    if col.startswith("AAA"):
        sample_cols.append(col)
    elif col.startswith("QC"):
        qc_cols.append(col)

# %%
df
# Out:
#        Unnamed: 0  Qidx  SOIidx   rtmed   start     end    mass        MaxInt  \
# 0               0     1       1  60.544  45.000  72.500  81.070   160,840.953
# 1               1     2       4 172.568 161.439 191.635  82.053    98,153.547
# 2               2     3       6 143.225 116.953 165.260  82.053   134,492.109
# 3               3     4       7 330.747 313.125 373.976  82.065    67,051.617
# 4               4     5       7 343.980 313.125 373.976  82.065    67,051.617
# ...           ...   ...     ...     ...     ...     ...     ...           ...
# 2,282       2,539 2,540   2,363 290.896 290.000 312.500 892.654 3,486,662.000
# 2,283       2,540 2,541   2,363 299.617 290.000 312.500 892.654 3,486,662.000
# 2,284       2,541 2,542   2,364  54.789  50.000  67.500 892.739   179,925.600
# 2,285       2,542 2,543   2,365  54.782  50.000  67.500 894.755   488,985.200
# 2,286       2,544 2,545   2,367  54.821  50.000  67.500 896.770   843,227.000
#
#               formula             anot  ...         QC_35         QC_36  \
# 0             [C6H9]+         C6H8_M+H  ...   142,100.734   129,631.148
# 1           [C4H6N2]+       C4H5N2_M+H  ...    72,917.398    73,738.812
# 2           [C4H6N2]+       C4H5N2_M+H  ...   117,823.602   122,279.500
# 3            [C5H8N]+        C5H7N_M+H  ...    58,493.379    55,851.680
# 4            [C5H8N]+        C5H7N_M+H  ...    25,015.951    21,309.277
# ...               ...              ...  ...           ...           ...
# 2,282  [C48H94NO11S]+  C48H93NO11S_M+H  ... 4,217,977.000 3,872,732.000
# 2,283  [C48H94NO11S]+  C48H93NO11S_M+H  ...    66,690.800    53,758.060
# 2,284    [C57H98NO6]+   C57H94O6_M+NH4  ...   190,497.800   173,043.300
# 2,285   [C57H100NO6]+   C57H96O6_M+NH4  ...   523,346.000   453,992.800
# 2,286   [C57H102NO6]+   C57H98O6_M+NH4  ...   998,584.700   897,026.200
#
#               QC_37         QC_38         QC_39         QC_40         QC_41  \
# 0       110,443.422   157,871.062   535,311.375   334,133.656   339,973.344
# 1        65,597.875    78,216.859    70,257.375    73,489.242    60,233.695
# 2       120,513.508   119,803.422   114,791.906   124,753.789   128,157.016
# 3        58,560.121    57,886.605    58,293.699    46,211.445    62,802.289
# 4        20,180.580    19,609.604    25,462.301    24,354.287    30,869.357
# ...             ...           ...           ...           ...           ...
# 2,282 3,356,819.000 3,444,360.000 3,641,683.000 4,531,348.000 4,375,519.000
# 2,283   100,864.900    88,069.460    94,612.190    87,438.410    78,174.880
# 2,284    57,476.910   174,392.000    47,625.360   135,338.900   154,609.500
# 2,285   133,935.100   509,662.500   114,995.100   381,900.100   421,614.900
# 2,286   235,440.700   809,741.600   178,420.900   678,957.200   785,135.600
#
#               QC_42         QC_43         QC_44
# 0       317,506.188   294,083.344   234,717.266
# 1        70,798.312    69,802.516    74,212.203
# 2       115,411.750   133,331.281   124,152.578
# 3        57,658.062    54,058.363    54,484.602
# 4        17,454.047    22,235.070    18,160.814
# ...             ...           ...           ...
# 2,282 3,864,418.000 3,730,628.000 5,249,600.000
# 2,283    61,854.690    92,978.760    69,441.320
# 2,284   179,258.000   171,145.200   161,171.100
# 2,285   503,656.400   439,513.500   434,035.700
# 2,286   895,259.400   788,261.100   768,748.800
#
# [2287 rows x 487 columns]

# %% [markdown]
# Seeing as this method is based on calculating principal components, as with PCA, there must not be any missing data.
#
# We will therefore first calculate missingness (NAs).
#
# We need to check for missing values in both the sample columns and the QC columns.

# %%
if dc.check_missingness(df, sample_cols+qc_cols):
    print("There are missing values. Consider imputing first, or use LOESS drift correction instead.")
else:
    print("\nThere is no missingness. We can proceed with the CPCA drift correction.")
# Out:
# Features (rows) with at least one NA: 0 / 2287
# Samples (cols) with at least one NA:
# Series([], dtype: int64)
#
# There is no missingness. We can proceed with the CPCA drift correction.

# %% [markdown]
# ### Visualise non-corrected data
#
# Now that we know we can proceed, let's visualise our data before drift correction with a PCA.

# %%
dc.pca_for_cpca_drift(
    df,
    sample_cols,  # list of col names, OR dict {group_name: [col names]}
    qc_cols,
    log_transform = True,
    title = "PCA",
)

# %% [markdown]
# We see some clear indication of instrumental drift in the QC samples.

# %% [markdown]
# ### Run drift correction based on CPCA

# %%
df_corrected = dc.run_cpca_drift_correction(
    df,
    sample_cols,
    qc_cols,
    n_comps=1
)
# Out:
# CPC explained variance: {'CPC1': np.float64(0.047)}

# %% [markdown]
# Let's plot the corrected data.

# %%
dc.pca_for_cpca_drift(
    df_corrected,
    sample_cols,  # list of col names, OR dict {group_name: [col names]}
    qc_cols,
    log_transform = True,
    title = "PCA",
)

# %% [markdown]
# There is some change, but still a signficant amount of drift is clearly visible from the PCA plot.
#
# We can play around with the n_comps variable which decides the number of components.

# %%
df_corrected_2comps = dc.run_cpca_drift_correction(
    df,
    sample_cols,
    qc_cols,
    n_comps=2
)

df_corrected_3comps = dc.run_cpca_drift_correction(
    df,
    sample_cols,
    qc_cols,
    n_comps=3
)

df_corrected_4comps = dc.run_cpca_drift_correction(
    df,
    sample_cols,
    qc_cols,
    n_comps=4
)
# Out:
# CPC explained variance: {'CPC1': np.float64(0.047), 'CPC2': np.float64(0.089)}
# CPC explained variance: {'CPC1': np.float64(0.047), 'CPC2': np.float64(0.089), 'CPC3': np.float64(0.062)}
# CPC explained variance: {'CPC1': np.float64(0.047), 'CPC2': np.float64(0.089), 'CPC3': np.float64(0.062), 'CPC4': np.float64(0.046)}

# %%
dc.pca_for_cpca_drift(
    df_corrected_2comps,
    sample_cols,  # list of col names, OR dict {group_name: [col names]}
    qc_cols,
    log_transform = True,
    title = "PCA with 2 components",
)

dc.pca_for_cpca_drift(
    df_corrected_3comps,
    sample_cols,  # list of col names, OR dict {group_name: [col names]}
    qc_cols,
    log_transform = True,
    title = "PCA with 3 components",
)

dc.pca_for_cpca_drift(
    df_corrected_4comps,
    sample_cols,  # list of col names, OR dict {group_name: [col names]}
    qc_cols,
    log_transform = True,
    title = "PCA with 4 components",
)

# %% [markdown]
# The correction methods with three and four components are already looking better. Let's calculate the centroids of the QC principal components and the distance of the QC points to them, to objectively decide which number of n_comps is most favourable.

# %%
dc.cpca_centroid(df_corrected, sample_cols, qc_cols, log_transform=True)
dc.cpca_centroid(df_corrected_2comps, sample_cols, qc_cols, log_transform=True)
dc.cpca_centroid(df_corrected_3comps, sample_cols, qc_cols, log_transform=True)
dc.cpca_centroid(df_corrected_4comps, sample_cols, qc_cols, log_transform=True)
# Out:
# The average distance of the points to the centroid is 6.660.
# The average distance of the points to the centroid is 7.944.
# The average distance of the points to the centroid is 1.849.
# The average distance of the points to the centroid is 2.251.
# 2.2509416651112293

# %% [markdown]
# According to this, the CPCA method with three principal components is most favourable in this case.
#
# We can go ahead and continue our metabolomics data analysis with this data set.

# %%
df_corrected_3comps
# Out:
#        Unnamed: 0  Qidx  SOIidx   rtmed   start     end    mass        MaxInt  \
# 0               0     1       1  60.544  45.000  72.500  81.070   160,840.953
# 1               1     2       4 172.568 161.439 191.635  82.053    98,153.547
# 2               2     3       6 143.225 116.953 165.260  82.053   134,492.109
# 3               3     4       7 330.747 313.125 373.976  82.065    67,051.617
# 4               4     5       7 343.980 313.125 373.976  82.065    67,051.617
# ...           ...   ...     ...     ...     ...     ...     ...           ...
# 2,282       2,539 2,540   2,363 290.896 290.000 312.500 892.654 3,486,662.000
# 2,283       2,540 2,541   2,363 299.617 290.000 312.500 892.654 3,486,662.000
# 2,284       2,541 2,542   2,364  54.789  50.000  67.500 892.739   179,925.600
# 2,285       2,542 2,543   2,365  54.782  50.000  67.500 894.755   488,985.200
# 2,286       2,544 2,545   2,367  54.821  50.000  67.500 896.770   843,227.000
#
#               formula             anot  ...         QC_35         QC_36  \
# 0             [C6H9]+         C6H8_M+H  ...   134,201.378   121,716.652
# 1           [C4H6N2]+       C4H5N2_M+H  ...    76,488.701    77,754.914
# 2           [C4H6N2]+       C4H5N2_M+H  ...   120,466.910   125,361.284
# 3            [C5H8N]+        C5H7N_M+H  ...    60,590.816    58,188.906
# 4            [C5H8N]+        C5H7N_M+H  ...    26,734.785    23,201.861
# ...               ...              ...  ...           ...           ...
# 2,282  [C48H94NO11S]+  C48H93NO11S_M+H  ... 4,873,269.064 4,638,220.136
# 2,283  [C48H94NO11S]+  C48H93NO11S_M+H  ...    94,922.483    86,176.900
# 2,284    [C57H98NO6]+   C57H94O6_M+NH4  ...   209,302.985   195,053.795
# 2,285   [C57H100NO6]+   C57H96O6_M+NH4  ...   574,917.951   515,026.068
# 2,286   [C57H102NO6]+   C57H98O6_M+NH4  ... 1,090,133.527 1,006,327.653
#
#               QC_37         QC_38         QC_39         QC_40         QC_41  \
# 0       105,110.406   151,398.431   524,193.983   318,993.906   322,126.443
# 1        69,414.055    82,880.137    81,202.109    84,522.111    70,822.062
# 2       123,620.363   123,798.365   126,378.429   135,945.215   138,438.511
# 3        60,810.258    60,415.006    62,144.502    50,231.349    66,830.331
# 4        21,940.368    21,609.380    28,639.477    27,755.257    34,336.715
# ...             ...           ...           ...           ...           ...
# 2,282 4,191,502.020 4,344,389.643 4,777,019.908 5,587,889.118 5,344,841.278
# 2,283   135,391.411   124,035.180   125,231.550   117,029.993   107,022.501
# 2,284    81,244.594   200,912.672    90,310.425   175,457.154   191,280.421
# 2,285   200,761.134   585,874.266   256,080.712   513,082.085   539,560.564
# 2,286   356,490.079   949,873.745   460,919.647   939,820.835 1,017,289.233
#
#               QC_42         QC_43         QC_44
# 0       301,912.641   275,656.649   215,208.092
# 1        80,115.299    79,188.791    84,404.918
# 2       124,387.851   142,043.838   133,753.800
# 3        61,294.845    57,809.475    58,451.701
# 4        20,564.553    25,500.161    21,621.256
# ...             ...           ...           ...
# 2,282 4,772,819.371 4,580,556.612 6,134,909.597
# 2,283    90,008.901   120,231.160    96,677.520
# 2,284   212,727.546   202,758.257   194,838.649
# 2,285   610,192.128   539,008.118   541,233.603
# 2,286 1,103,739.770   981,474.638   978,352.995
#
# [2287 rows x 487 columns]
